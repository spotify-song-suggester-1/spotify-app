# %% [markdown]
# # Collecting Data from the Spotify Web API using Spotipy
#
# ## About the Spotipy Library:
#
# From the [official Spotipy docs](https://spotipy.readthedocs.io/en/latest/):
# >"Spotipy is a lightweight Python library for the Spotify Web API. With Spotipy you get full access to all of the music data provided by the Spotify platform."
#
#
# ## About using the Spotify Web API:
#
# Spotify offers a number of [API endpoints](https://beta.developer.spotify.com/documentation/web-api/reference/) to access the Spotify data. In this notebook, I used the following:
#
# - [search endpoint](https://beta.developer.spotify.com/documentation/web-api/reference/search/search/) to get the track IDs
# - [audio features endpoint](https://beta.developer.spotify.com/documentation/web-api/reference/tracks/get-several-audio-features/) to get the corresponding audio features.

# %% [markdown]
# ### Set Spotipy Credentials.

# %%
# pip install spotipy.
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.6/dist-packages (2.9.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from spotipy) (1.12.0)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from spotipy) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->spotipy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->spotipy) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->spotipy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->spotipy) (1.24.3)

# %%
# imports.
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# spotify credentials.
cid = '51c2d40e57e74fbb852374c80b4f0054'
secret = '8b0cafe24a7c45818f2b01f12fec13e5'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Song Tracks Data.

# %%
# imports.
import timeit
import time

# timeit library to measure the time needed to run this code.
start = timeit.default_timer()

# empty lists where the results are going to be stored
artist_name = []
track_name = []
popularity = []
track_id = []

for i in range(0,2000,50):
    # search by year.
    #track_results = sp.search(q='year:2020', limit=50, offset=i, market='EU')
    # search by genre.
    #track_results = sp.search(q='genre:dance', limit=50, offset=i, market='US')
    # search year and genre.
    track_results = sp.search(q='year:2018 AND tag:hipster', limit=50, offset=i, market='US')

    #time.sleep(0.50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        
stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)
track_results['tracks']
# Out:
# Time to run this code (in seconds): 7.158979541000008
# {'href': 'https://api.spotify.com/v1/search?query=year%3A2018+AND+tag%3Ahipster&type=track&market=US&offset=1950&limit=50',
#  'items': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5vkLZWQUTgsmJ6WDCD4DPf'},
#       'href': 'https://api.spotify.com/v1/artists/5vkLZWQUTgsmJ6WDCD4DPf',
#       'id': '5vkLZWQUTgsmJ6WDCD4DPf',
#       'name': 'WØLV',
#       'type': 'artist',
#       'uri': 'spotify:artist:5vkLZWQUTgsmJ6WDCD4DPf'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2PwciAvErbhfgBRJN6jYN3'},
#     'href': 'https://api.spotify.com/v1/albums/2PwciAvErbhfgBRJN6jYN3',
#     'id': '2PwciAvErbhfgBRJN6jYN3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c0e29b705d1fd548f708fa4e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c0e29b705d1fd548f708fa4e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c0e29b705d1fd548f708fa4e',
#       'width': 64}],
#     'name': 'Taste the Sun',
#     'release_date': '2018-09-07',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:2PwciAvErbhfgBRJN6jYN3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5vkLZWQUTgsmJ6WDCD4DPf'},
#      'href': 'https://api.spotify.com/v1/artists/5vkLZWQUTgsmJ6WDCD4DPf',
#      'id': '5vkLZWQUTgsmJ6WDCD4DPf',
#      'name': 'WØLV',
#      'type': 'artist',
#      'uri': 'spotify:artist:5vkLZWQUTgsmJ6WDCD4DPf'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7yp7vvBAG1xp89LD4kvbFB'},
#      'href': 'https://api.spotify.com/v1/artists/7yp7vvBAG1xp89LD4kvbFB',
#      'id': '7yp7vvBAG1xp89LD4kvbFB',
#      'name': 'Rebecca_1147',
#      'type': 'artist',
#      'uri': 'spotify:artist:7yp7vvBAG1xp89LD4kvbFB'}],
#    'disc_number': 1,
#    'duration_ms': 188284,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEUD91893062'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05Aeb9fNNQ7opuuNtrWNls'},
#    'href': 'https://api.spotify.com/v1/tracks/05Aeb9fNNQ7opuuNtrWNls',
#    'id': '05Aeb9fNNQ7opuuNtrWNls',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Taste the Sun',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cc7b1d25ac032784019310d8f30cdb591ca03037?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:05Aeb9fNNQ7opuuNtrWNls'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/388qO01DE036An8RrenDBr'},
#       'href': 'https://api.spotify.com/v1/artists/388qO01DE036An8RrenDBr',
#       'id': '388qO01DE036An8RrenDBr',
#       'name': 'Izabela Reis',
#       'type': 'artist',
#       'uri': 'spotify:artist:388qO01DE036An8RrenDBr'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Rn5JWUoeDramqIXgGPsnP'},
#     'href': 'https://api.spotify.com/v1/albums/2Rn5JWUoeDramqIXgGPsnP',
#     'id': '2Rn5JWUoeDramqIXgGPsnP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730c2939daf75d01e5c10f8df6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020c2939daf75d01e5c10f8df6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510c2939daf75d01e5c10f8df6',
#       'width': 64}],
#     'name': 'Aurora',
#     'release_date': '2018-12-14',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:2Rn5JWUoeDramqIXgGPsnP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/388qO01DE036An8RrenDBr'},
#      'href': 'https://api.spotify.com/v1/artists/388qO01DE036An8RrenDBr',
#      'id': '388qO01DE036An8RrenDBr',
#      'name': 'Izabela Reis',
#      'type': 'artist',
#      'uri': 'spotify:artist:388qO01DE036An8RrenDBr'}],
#    'disc_number': 1,
#    'duration_ms': 200039,
#    'explicit': False,
#    'external_ids': {'isrc': 'RUA1H1817265'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05AiS2PgaA01VQoMy8ndoN'},
#    'href': 'https://api.spotify.com/v1/tracks/05AiS2PgaA01VQoMy8ndoN',
#    'id': '05AiS2PgaA01VQoMy8ndoN',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Eu Sei',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/83544ddb11fdd85c1c54cd52e31a7b7b1a6045c2?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:05AiS2PgaA01VQoMy8ndoN'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3M8sLWbS13j8JgYEUowidq'},
#       'href': 'https://api.spotify.com/v1/artists/3M8sLWbS13j8JgYEUowidq',
#       'id': '3M8sLWbS13j8JgYEUowidq',
#       'name': 'Fresh N Dope',
#       'type': 'artist',
#       'uri': 'spotify:artist:3M8sLWbS13j8JgYEUowidq'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0TIKMDnedfu6w0FxxdMVeZ'},
#     'href': 'https://api.spotify.com/v1/albums/0TIKMDnedfu6w0FxxdMVeZ',
#     'id': '0TIKMDnedfu6w0FxxdMVeZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739740800a1ff1611be800be45',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029740800a1ff1611be800be45',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519740800a1ff1611be800be45',
#       'width': 64}],
#     'name': 'Fresh N Dope Mixtape (Hosted By Wac Toja)',
#     'release_date': '2018-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:0TIKMDnedfu6w0FxxdMVeZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7HarXmq3zshAFoeA3z1nwT'},
#      'href': 'https://api.spotify.com/v1/artists/7HarXmq3zshAFoeA3z1nwT',
#      'id': '7HarXmq3zshAFoeA3z1nwT',
#      'name': 'Jeleśniański',
#      'type': 'artist',
#      'uri': 'spotify:artist:7HarXmq3zshAFoeA3z1nwT'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3M8sLWbS13j8JgYEUowidq'},
#      'href': 'https://api.spotify.com/v1/artists/3M8sLWbS13j8JgYEUowidq',
#      'id': '3M8sLWbS13j8JgYEUowidq',
#      'name': 'Fresh N Dope',
#      'type': 'artist',
#      'uri': 'spotify:artist:3M8sLWbS13j8JgYEUowidq'}],
#    'disc_number': 1,
#    'duration_ms': 186424,
#    'explicit': True,
#    'external_ids': {'isrc': 'PLUM71800817'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05ApDlCmomIp481p5bejIW'},
#    'href': 'https://api.spotify.com/v1/tracks/05ApDlCmomIp481p5bejIW',
#    'id': '05ApDlCmomIp481p5bejIW',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Akademik',
#    'popularity': 3,
#    'preview_url': None,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:05ApDlCmomIp481p5bejIW'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5LCDv4TvYRQD5ehflOBEh4'},
#       'href': 'https://api.spotify.com/v1/artists/5LCDv4TvYRQD5ehflOBEh4',
#       'id': '5LCDv4TvYRQD5ehflOBEh4',
#       'name': 'Wilfrido Vargas',
#       'type': 'artist',
#       'uri': 'spotify:artist:5LCDv4TvYRQD5ehflOBEh4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3bCXIdh7aujWtPJnIyOMCb'},
#     'href': 'https://api.spotify.com/v1/albums/3bCXIdh7aujWtPJnIyOMCb',
#     'id': '3bCXIdh7aujWtPJnIyOMCb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273eca206bc6be752c21dcd3764',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02eca206bc6be752c21dcd3764',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851eca206bc6be752c21dcd3764',
#       'width': 64}],
#     'name': 'El Funcionario',
#     'release_date': '2018-05-19',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3bCXIdh7aujWtPJnIyOMCb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5LCDv4TvYRQD5ehflOBEh4'},
#      'href': 'https://api.spotify.com/v1/artists/5LCDv4TvYRQD5ehflOBEh4',
#      'id': '5LCDv4TvYRQD5ehflOBEh4',
#      'name': 'Wilfrido Vargas',
#      'type': 'artist',
#      'uri': 'spotify:artist:5LCDv4TvYRQD5ehflOBEh4'}],
#    'disc_number': 1,
#    'duration_ms': 199533,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJ3V1497710'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05BBQrQ2Xb57LwFkuBFCGT'},
#    'href': 'https://api.spotify.com/v1/tracks/05BBQrQ2Xb57LwFkuBFCGT',
#    'id': '05BBQrQ2Xb57LwFkuBFCGT',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Vete Lejos (Amelia)',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/32777faa7c6bb21fa50f211c436030d1e1926216?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:05BBQrQ2Xb57LwFkuBFCGT'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3YZxGuk1m0pUoyZRCMcLDh'},
#       'href': 'https://api.spotify.com/v1/artists/3YZxGuk1m0pUoyZRCMcLDh',
#       'id': '3YZxGuk1m0pUoyZRCMcLDh',
#       'name': 'Mohamad Outhnawt',
#       'type': 'artist',
#       'uri': 'spotify:artist:3YZxGuk1m0pUoyZRCMcLDh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4wTvWgCxE9ECJetnYSQ3Yv'},
#     'href': 'https://api.spotify.com/v1/albums/4wTvWgCxE9ECJetnYSQ3Yv',
#     'id': '4wTvWgCxE9ECJetnYSQ3Yv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733732bd97f625d68c410bb963',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023732bd97f625d68c410bb963',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513732bd97f625d68c410bb963',
#       'width': 64}],
#     'name': 'Nigh Bismillah',
#     'release_date': '2018-10-26',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:4wTvWgCxE9ECJetnYSQ3Yv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3YZxGuk1m0pUoyZRCMcLDh'},
#      'href': 'https://api.spotify.com/v1/artists/3YZxGuk1m0pUoyZRCMcLDh',
#      'id': '3YZxGuk1m0pUoyZRCMcLDh',
#      'name': 'Mohamad Outhnawt',
#      'type': 'artist',
#      'uri': 'spotify:artist:3YZxGuk1m0pUoyZRCMcLDh'}],
#    'disc_number': 1,
#    'duration_ms': 333392,
#    'explicit': False,
#    'external_ids': {'isrc': 'ESA011821902'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05BECWXOQA9nRhsolRu48x'},
#    'href': 'https://api.spotify.com/v1/tracks/05BECWXOQA9nRhsolRu48x',
#    'id': '05BECWXOQA9nRhsolRu48x',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Dalb Irbbi',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/446e256f8c905274e4c330d281ec7c41b6096aa0?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:05BECWXOQA9nRhsolRu48x'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05BimyoMbuMGEBJjSRDK0a'},
#       'href': 'https://api.spotify.com/v1/artists/05BimyoMbuMGEBJjSRDK0a',
#       'id': '05BimyoMbuMGEBJjSRDK0a',
#       'name': 'Bolivar Peralta',
#       'type': 'artist',
#       'uri': 'spotify:artist:05BimyoMbuMGEBJjSRDK0a'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/38f27ItMVeolDDQcFJKMyu'},
#     'href': 'https://api.spotify.com/v1/albums/38f27ItMVeolDDQcFJKMyu',
#     'id': '38f27ItMVeolDDQcFJKMyu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273207aad17abb49acc1e9b8f9b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02207aad17abb49acc1e9b8f9b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851207aad17abb49acc1e9b8f9b',
#       'width': 64}],
#     'name': '15 Exitos',
#     'release_date': '2018-05-04',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:38f27ItMVeolDDQcFJKMyu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05BimyoMbuMGEBJjSRDK0a'},
#      'href': 'https://api.spotify.com/v1/artists/05BimyoMbuMGEBJjSRDK0a',
#      'id': '05BimyoMbuMGEBJjSRDK0a',
#      'name': 'Bolivar Peralta',
#      'type': 'artist',
#      'uri': 'spotify:artist:05BimyoMbuMGEBJjSRDK0a'}],
#    'disc_number': 1,
#    'duration_ms': 173733,
#    'explicit': False,
#    'external_ids': {'isrc': 'DOA251800028'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05C2svDk8favywkM6fBlv0'},
#    'href': 'https://api.spotify.com/v1/tracks/05C2svDk8favywkM6fBlv0',
#    'id': '05C2svDk8favywkM6fBlv0',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Espero por Mi Morena',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c853cd196f880a6430c63106519f59182dc128ea?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:05C2svDk8favywkM6fBlv0'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Anz2KY3x2hKdhUxaDK1Zm'},
#       'href': 'https://api.spotify.com/v1/artists/2Anz2KY3x2hKdhUxaDK1Zm',
#       'id': '2Anz2KY3x2hKdhUxaDK1Zm',
#       'name': 'Мила Роберт',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Anz2KY3x2hKdhUxaDK1Zm'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5jMiV4YTcRDhy2Y4Qexzkm'},
#     'href': 'https://api.spotify.com/v1/albums/5jMiV4YTcRDhy2Y4Qexzkm',
#     'id': '5jMiV4YTcRDhy2Y4Qexzkm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736a947cbc6dd4d4c350dc415e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026a947cbc6dd4d4c350dc415e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516a947cbc6dd4d4c350dc415e',
#       'width': 64}],
#     'name': 'Наше си е, Саше',
#     'release_date': '2018-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5jMiV4YTcRDhy2Y4Qexzkm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Anz2KY3x2hKdhUxaDK1Zm'},
#      'href': 'https://api.spotify.com/v1/artists/2Anz2KY3x2hKdhUxaDK1Zm',
#      'id': '2Anz2KY3x2hKdhUxaDK1Zm',
#      'name': 'Мила Роберт',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Anz2KY3x2hKdhUxaDK1Zm'}],
#    'disc_number': 1,
#    'duration_ms': 165748,
#    'explicit': False,
#    'external_ids': {'isrc': 'BGA261578009'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05CZU4k4WXD0ZTYpF87t4G'},
#    'href': 'https://api.spotify.com/v1/tracks/05CZU4k4WXD0ZTYpF87t4G',
#    'id': '05CZU4k4WXD0ZTYpF87t4G',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Наше си е, Саше',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5730496662ce457589b011fa94425ded9eeca125?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05CZU4k4WXD0ZTYpF87t4G'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bOYFg7eEyHMA6wBK99Rv2'},
#       'href': 'https://api.spotify.com/v1/artists/2bOYFg7eEyHMA6wBK99Rv2',
#       'id': '2bOYFg7eEyHMA6wBK99Rv2',
#       'name': 'LAZZI',
#       'type': 'artist',
#       'uri': 'spotify:artist:2bOYFg7eEyHMA6wBK99Rv2'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7hHj2eVrqt30CBXhRdkdAK'},
#     'href': 'https://api.spotify.com/v1/albums/7hHj2eVrqt30CBXhRdkdAK',
#     'id': '7hHj2eVrqt30CBXhRdkdAK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273efeb482a3579e25f1020646f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02efeb482a3579e25f1020646f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851efeb482a3579e25f1020646f',
#       'width': 64}],
#     'name': 'Bumbaa',
#     'release_date': '2018-06-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7hHj2eVrqt30CBXhRdkdAK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bOYFg7eEyHMA6wBK99Rv2'},
#      'href': 'https://api.spotify.com/v1/artists/2bOYFg7eEyHMA6wBK99Rv2',
#      'id': '2bOYFg7eEyHMA6wBK99Rv2',
#      'name': 'LAZZI',
#      'type': 'artist',
#      'uri': 'spotify:artist:2bOYFg7eEyHMA6wBK99Rv2'}],
#    'disc_number': 1,
#    'duration_ms': 150836,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCADT1844652'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05CboX8OTxRM19caluPOnb'},
#    'href': 'https://api.spotify.com/v1/tracks/05CboX8OTxRM19caluPOnb',
#    'id': '05CboX8OTxRM19caluPOnb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bumbaa',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/89cc7ffd4f9338f91bc8f16bb3daed5dc00e11c3?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05CboX8OTxRM19caluPOnb'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1CCntO8047hgF60wHFL77T'},
#       'href': 'https://api.spotify.com/v1/artists/1CCntO8047hgF60wHFL77T',
#       'id': '1CCntO8047hgF60wHFL77T',
#       'name': 'Hann',
#       'type': 'artist',
#       'uri': 'spotify:artist:1CCntO8047hgF60wHFL77T'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Iop4vp7rCDTZqFJRxVwqL'},
#     'href': 'https://api.spotify.com/v1/albums/3Iop4vp7rCDTZqFJRxVwqL',
#     'id': '3Iop4vp7rCDTZqFJRxVwqL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27346a8b355290be18e3f8b6952',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0246a8b355290be18e3f8b6952',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485146a8b355290be18e3f8b6952',
#       'width': 64}],
#     'name': 'Hann',
#     'release_date': '2018-12-04',
#     'release_date_precision': 'day',
#     'total_tracks': 49,
#     'type': 'album',
#     'uri': 'spotify:album:3Iop4vp7rCDTZqFJRxVwqL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1CCntO8047hgF60wHFL77T'},
#      'href': 'https://api.spotify.com/v1/artists/1CCntO8047hgF60wHFL77T',
#      'id': '1CCntO8047hgF60wHFL77T',
#      'name': 'Hann',
#      'type': 'artist',
#      'uri': 'spotify:artist:1CCntO8047hgF60wHFL77T'}],
#    'disc_number': 1,
#    'duration_ms': 210795,
#    'explicit': False,
#    'external_ids': {'isrc': 'RUA1D1825238'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05E20ZKxIXRCCTqXcydKvg'},
#    'href': 'https://api.spotify.com/v1/tracks/05E20ZKxIXRCCTqXcydKvg',
#    'id': '05E20ZKxIXRCCTqXcydKvg',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Выключи боль',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2ca7dd4229a5167107c6b49b222b234142fcb9e6?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05E20ZKxIXRCCTqXcydKvg'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rrGMzziGpsTFTSeCEs1ou'},
#       'href': 'https://api.spotify.com/v1/artists/5rrGMzziGpsTFTSeCEs1ou',
#       'id': '5rrGMzziGpsTFTSeCEs1ou',
#       'name': 'Affect',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rrGMzziGpsTFTSeCEs1ou'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4OBE68cwB4QFv2ui0qFHag'},
#     'href': 'https://api.spotify.com/v1/albums/4OBE68cwB4QFv2ui0qFHag',
#     'id': '4OBE68cwB4QFv2ui0qFHag',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27322af52c0052f18a7ac79010c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0222af52c0052f18a7ac79010c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485122af52c0052f18a7ac79010c',
#       'width': 64}],
#     'name': 'Наследство',
#     'release_date': '2018-04-16',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:4OBE68cwB4QFv2ui0qFHag'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rrGMzziGpsTFTSeCEs1ou'},
#      'href': 'https://api.spotify.com/v1/artists/5rrGMzziGpsTFTSeCEs1ou',
#      'id': '5rrGMzziGpsTFTSeCEs1ou',
#      'name': 'Affect',
#      'type': 'artist',
#      'uri': 'spotify:artist:5rrGMzziGpsTFTSeCEs1ou'}],
#    'disc_number': 1,
#    'duration_ms': 269080,
#    'explicit': False,
#    'external_ids': {'isrc': 'SEYOK1828716'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05EJshxMP7cls0HXxE5WWL'},
#    'href': 'https://api.spotify.com/v1/tracks/05EJshxMP7cls0HXxE5WWL',
#    'id': '05EJshxMP7cls0HXxE5WWL',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Мойте кафеви очи',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ebbb39749866eaaad75189334adf6e37850340d3?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:05EJshxMP7cls0HXxE5WWL'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24Pl5vknldjXTM3KtGEv9R'},
#       'href': 'https://api.spotify.com/v1/artists/24Pl5vknldjXTM3KtGEv9R',
#       'id': '24Pl5vknldjXTM3KtGEv9R',
#       'name': 'Hase',
#       'type': 'artist',
#       'uri': 'spotify:artist:24Pl5vknldjXTM3KtGEv9R'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0UAWKdS1Vv6EKatELCjk3C'},
#     'href': 'https://api.spotify.com/v1/albums/0UAWKdS1Vv6EKatELCjk3C',
#     'id': '0UAWKdS1Vv6EKatELCjk3C',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ae815d0de65ddbf695e98bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ae815d0de65ddbf695e98bf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ae815d0de65ddbf695e98bf',
#       'width': 64}],
#     'name': 'Najlepszego',
#     'release_date': '2018-08-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0UAWKdS1Vv6EKatELCjk3C'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24Pl5vknldjXTM3KtGEv9R'},
#      'href': 'https://api.spotify.com/v1/artists/24Pl5vknldjXTM3KtGEv9R',
#      'id': '24Pl5vknldjXTM3KtGEv9R',
#      'name': 'Hase',
#      'type': 'artist',
#      'uri': 'spotify:artist:24Pl5vknldjXTM3KtGEv9R'}],
#    'disc_number': 1,
#    'duration_ms': 220551,
#    'explicit': False,
#    'external_ids': {'isrc': 'PLS411800016'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05En7rxUrMMIWSDoKetQJE'},
#    'href': 'https://api.spotify.com/v1/tracks/05En7rxUrMMIWSDoKetQJE',
#    'id': '05En7rxUrMMIWSDoKetQJE',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Najlepszego',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/63699b97c4d690eb288c8abf2ed3b799e740b40a?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05En7rxUrMMIWSDoKetQJE'},
#   {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/08UTHYSjmtRNQ8zK3JnnZ2'},
#     'href': 'https://api.spotify.com/v1/albums/08UTHYSjmtRNQ8zK3JnnZ2',
#     'id': '08UTHYSjmtRNQ8zK3JnnZ2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733e5f1831658a1af9beeb6398',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023e5f1831658a1af9beeb6398',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513e5f1831658a1af9beeb6398',
#       'width': 64}],
#     'name': 'Budda Bar Best Off, Vol. 3',
#     'release_date': '2018-04-27',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:08UTHYSjmtRNQ8zK3JnnZ2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hCKWhFiEID6G0QAkPAHR2'},
#      'href': 'https://api.spotify.com/v1/artists/3hCKWhFiEID6G0QAkPAHR2',
#      'id': '3hCKWhFiEID6G0QAkPAHR2',
#      'name': 'Yoga',
#      'type': 'artist',
#      'uri': 'spotify:artist:3hCKWhFiEID6G0QAkPAHR2'}],
#    'disc_number': 1,
#    'duration_ms': 307000,
#    'explicit': False,
#    'external_ids': {'isrc': 'BGA261850119'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05F6JPcRh3yrmbyAEtJqEq'},
#    'href': 'https://api.spotify.com/v1/tracks/05F6JPcRh3yrmbyAEtJqEq',
#    'id': '05F6JPcRh3yrmbyAEtJqEq',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Hatha Yoga 3- Standing Yoga Poses (20 min), Part 3',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5f653ac2f2883452f9576c0f6016128ed2db2ae4?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 19,
#    'type': 'track',
#    'uri': 'spotify:track:05F6JPcRh3yrmbyAEtJqEq'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/32vpj3OfAguCApf3kgX6Hi'},
#       'href': 'https://api.spotify.com/v1/artists/32vpj3OfAguCApf3kgX6Hi',
#       'id': '32vpj3OfAguCApf3kgX6Hi',
#       'name': 'VKL',
#       'type': 'artist',
#       'uri': 'spotify:artist:32vpj3OfAguCApf3kgX6Hi'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/63TB3p6JwwW8P9wmeu12DS'},
#     'href': 'https://api.spotify.com/v1/albums/63TB3p6JwwW8P9wmeu12DS',
#     'id': '63TB3p6JwwW8P9wmeu12DS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273743ff01709030db98bbd61bd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02743ff01709030db98bbd61bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851743ff01709030db98bbd61bd',
#       'width': 64}],
#     'name': 'Over Control',
#     'release_date': '2018-02-18',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:63TB3p6JwwW8P9wmeu12DS'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/32vpj3OfAguCApf3kgX6Hi'},
#      'href': 'https://api.spotify.com/v1/artists/32vpj3OfAguCApf3kgX6Hi',
#      'id': '32vpj3OfAguCApf3kgX6Hi',
#      'name': 'VKL',
#      'type': 'artist',
#      'uri': 'spotify:artist:32vpj3OfAguCApf3kgX6Hi'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2xW33QJdQkUruZADfAe7SU'},
#      'href': 'https://api.spotify.com/v1/artists/2xW33QJdQkUruZADfAe7SU',
#      'id': '2xW33QJdQkUruZADfAe7SU',
#      'name': 'Mona',
#      'type': 'artist',
#      'uri': 'spotify:artist:2xW33QJdQkUruZADfAe7SU'}],
#    'disc_number': 1,
#    'duration_ms': 181258,
#    'explicit': True,
#    'external_ids': {'isrc': 'THMOB1804023'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05FUsCBqsu9Y0hQSryVjX2'},
#    'href': 'https://api.spotify.com/v1/tracks/05FUsCBqsu9Y0hQSryVjX2',
#    'id': '05FUsCBqsu9Y0hQSryVjX2',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'OldBoy',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f561a68105d21f29b3cb9c43e9de146453991571?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05FUsCBqsu9Y0hQSryVjX2'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CEb6FBQ8gedT2X9w3Oe3p'},
#       'href': 'https://api.spotify.com/v1/artists/6CEb6FBQ8gedT2X9w3Oe3p',
#       'id': '6CEb6FBQ8gedT2X9w3Oe3p',
#       'name': 'אנטישפע',
#       'type': 'artist',
#       'uri': 'spotify:artist:6CEb6FBQ8gedT2X9w3Oe3p'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/60DeTlimDbxCN1VI4HVPEm'},
#     'href': 'https://api.spotify.com/v1/albums/60DeTlimDbxCN1VI4HVPEm',
#     'id': '60DeTlimDbxCN1VI4HVPEm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e926b82e2b5578361cdf33c4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e926b82e2b5578361cdf33c4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e926b82e2b5578361cdf33c4',
#       'width': 64}],
#     'name': 'אנטישפע',
#     'release_date': '2018-12-09',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:60DeTlimDbxCN1VI4HVPEm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CEb6FBQ8gedT2X9w3Oe3p'},
#      'href': 'https://api.spotify.com/v1/artists/6CEb6FBQ8gedT2X9w3Oe3p',
#      'id': '6CEb6FBQ8gedT2X9w3Oe3p',
#      'name': 'אנטישפע',
#      'type': 'artist',
#      'uri': 'spotify:artist:6CEb6FBQ8gedT2X9w3Oe3p'}],
#    'disc_number': 1,
#    'duration_ms': 244573,
#    'explicit': False,
#    'external_ids': {'isrc': 'IL1041802603'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05FXAoMZOAwLcie3fTDPO1'},
#    'href': 'https://api.spotify.com/v1/tracks/05FXAoMZOAwLcie3fTDPO1',
#    'id': '05FXAoMZOAwLcie3fTDPO1',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'אני מנצח אותם בשישה מהלכים',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/231c25ad8c026b3eb3087887a1f4d603e6487868?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:05FXAoMZOAwLcie3fTDPO1'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gknWXCKuVqcm1gEYxWnZQ'},
#       'href': 'https://api.spotify.com/v1/artists/2gknWXCKuVqcm1gEYxWnZQ',
#       'id': '2gknWXCKuVqcm1gEYxWnZQ',
#       'name': 'Rozpor',
#       'type': 'artist',
#       'uri': 'spotify:artist:2gknWXCKuVqcm1gEYxWnZQ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5fdvrL6TR4kndYg7MDtgJY'},
#     'href': 'https://api.spotify.com/v1/albums/5fdvrL6TR4kndYg7MDtgJY',
#     'id': '5fdvrL6TR4kndYg7MDtgJY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738cc80bbed481e906212937a2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028cc80bbed481e906212937a2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518cc80bbed481e906212937a2',
#       'width': 64}],
#     'name': 'Su Uchilny Zido Bolsevycky Fetaci!!!',
#     'release_date': '2018-06-28',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:5fdvrL6TR4kndYg7MDtgJY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gknWXCKuVqcm1gEYxWnZQ'},
#      'href': 'https://api.spotify.com/v1/artists/2gknWXCKuVqcm1gEYxWnZQ',
#      'id': '2gknWXCKuVqcm1gEYxWnZQ',
#      'name': 'Rozpor',
#      'type': 'artist',
#      'uri': 'spotify:artist:2gknWXCKuVqcm1gEYxWnZQ'}],
#    'disc_number': 1,
#    'duration_ms': 194013,
#    'explicit': False,
#    'external_ids': {'isrc': 'ushm21862762'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05GDsWEnpQtwhYW26dHa2E'},
#    'href': 'https://api.spotify.com/v1/tracks/05GDsWEnpQtwhYW26dHa2E',
#    'id': '05GDsWEnpQtwhYW26dHa2E',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Tv - Choroba',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f5748fe4a3d65e3bf65babe8371d8b43d9c01cc6?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 18,
#    'type': 'track',
#    'uri': 'spotify:track:05GDsWEnpQtwhYW26dHa2E'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/03xLoZynfduEfjG6T6jFCi'},
#       'href': 'https://api.spotify.com/v1/artists/03xLoZynfduEfjG6T6jFCi',
#       'id': '03xLoZynfduEfjG6T6jFCi',
#       'name': 'Senziwe',
#       'type': 'artist',
#       'uri': 'spotify:artist:03xLoZynfduEfjG6T6jFCi'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6bZcN0ta5t1OpK5gOOt9S1'},
#     'href': 'https://api.spotify.com/v1/albums/6bZcN0ta5t1OpK5gOOt9S1',
#     'id': '6bZcN0ta5t1OpK5gOOt9S1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fa3c829f4f0bb1e1ef60701f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fa3c829f4f0bb1e1ef60701f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fa3c829f4f0bb1e1ef60701f',
#       'width': 64}],
#     'name': 'Izulu',
#     'release_date': '2018-04-19',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:6bZcN0ta5t1OpK5gOOt9S1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/03xLoZynfduEfjG6T6jFCi'},
#      'href': 'https://api.spotify.com/v1/artists/03xLoZynfduEfjG6T6jFCi',
#      'id': '03xLoZynfduEfjG6T6jFCi',
#      'name': 'Senziwe',
#      'type': 'artist',
#      'uri': 'spotify:artist:03xLoZynfduEfjG6T6jFCi'}],
#    'disc_number': 1,
#    'duration_ms': 254693,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZCE61829476'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05GOLaLJAO0SxvkWCbHo6f'},
#    'href': 'https://api.spotify.com/v1/tracks/05GOLaLJAO0SxvkWCbHo6f',
#    'id': '05GOLaLJAO0SxvkWCbHo6f',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ebheneza',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8399bbe6a319afb850d0aa0a8678ce4e7c1f123c?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:05GOLaLJAO0SxvkWCbHo6f'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZcUq530NdIaJkvLzDhTrZ'},
#       'href': 'https://api.spotify.com/v1/artists/1ZcUq530NdIaJkvLzDhTrZ',
#       'id': '1ZcUq530NdIaJkvLzDhTrZ',
#       'name': 'Relaxation mentale',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ZcUq530NdIaJkvLzDhTrZ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/45I0cSdECEvNBMBvLZjPT0'},
#     'href': 'https://api.spotify.com/v1/albums/45I0cSdECEvNBMBvLZjPT0',
#     'id': '45I0cSdECEvNBMBvLZjPT0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dd947476135ed94733a4b5f0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dd947476135ed94733a4b5f0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dd947476135ed94733a4b5f0',
#       'width': 64}],
#     'name': "Stimulation du cerveau (Musique de fond relaxante pour l'étude et la concentration, Vite apprentissage)",
#     'release_date': '2018-04-23',
#     'release_date_precision': 'day',
#     'total_tracks': 50,
#     'type': 'album',
#     'uri': 'spotify:album:45I0cSdECEvNBMBvLZjPT0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZcUq530NdIaJkvLzDhTrZ'},
#      'href': 'https://api.spotify.com/v1/artists/1ZcUq530NdIaJkvLzDhTrZ',
#      'id': '1ZcUq530NdIaJkvLzDhTrZ',
#      'name': 'Relaxation mentale',
#      'type': 'artist',
#      'uri': 'spotify:artist:1ZcUq530NdIaJkvLzDhTrZ'}],
#    'disc_number': 1,
#    'duration_ms': 201900,
#    'explicit': False,
#    'external_ids': {'isrc': 'PLS921678827'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05GPVoaJZhQZMLuz2QgaNL'},
#    'href': 'https://api.spotify.com/v1/tracks/05GPVoaJZhQZMLuz2QgaNL',
#    'id': '05GPVoaJZhQZMLuz2QgaNL',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Calme et harmonie',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3494a313c0c762696a334f356bcf98d12b66d4d7?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:05GPVoaJZhQZMLuz2QgaNL'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rgRefCmpaJQ3h4Zq2WyQS'},
#       'href': 'https://api.spotify.com/v1/artists/6rgRefCmpaJQ3h4Zq2WyQS',
#       'id': '6rgRefCmpaJQ3h4Zq2WyQS',
#       'name': 'Humanizer',
#       'type': 'artist',
#       'uri': 'spotify:artist:6rgRefCmpaJQ3h4Zq2WyQS'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1QIoGvWpHaTgKHgm4i4Q5X'},
#     'href': 'https://api.spotify.com/v1/albums/1QIoGvWpHaTgKHgm4i4Q5X',
#     'id': '1QIoGvWpHaTgKHgm4i4Q5X',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27348e9039f2dcff8306a476b5d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0248e9039f2dcff8306a476b5d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485148e9039f2dcff8306a476b5d',
#       'width': 64}],
#     'name': 'Divine Golden Blood',
#     'release_date': '2018-11-30',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:1QIoGvWpHaTgKHgm4i4Q5X'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rgRefCmpaJQ3h4Zq2WyQS'},
#      'href': 'https://api.spotify.com/v1/artists/6rgRefCmpaJQ3h4Zq2WyQS',
#      'id': '6rgRefCmpaJQ3h4Zq2WyQS',
#      'name': 'Humanizer',
#      'type': 'artist',
#      'uri': 'spotify:artist:6rgRefCmpaJQ3h4Zq2WyQS'}],
#    'disc_number': 1,
#    'duration_ms': 155838,
#    'explicit': True,
#    'external_ids': {'isrc': 'usl4q1884949'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05GSsejQZ6DOwCbQreqDsT'},
#    'href': 'https://api.spotify.com/v1/tracks/05GSsejQZ6DOwCbQreqDsT',
#    'id': '05GSsejQZ6DOwCbQreqDsT',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Divine Golden Blood',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4f25a40c0e8474424fcde24fbf43a6fba8729988?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05GSsejQZ6DOwCbQreqDsT'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LCRnJhAmGfgnYMkcOFvgu'},
#       'href': 'https://api.spotify.com/v1/artists/4LCRnJhAmGfgnYMkcOFvgu',
#       'id': '4LCRnJhAmGfgnYMkcOFvgu',
#       'name': 'TAMIREL',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LCRnJhAmGfgnYMkcOFvgu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6ahyCttugbfTL3jhwglH4M'},
#     'href': 'https://api.spotify.com/v1/albums/6ahyCttugbfTL3jhwglH4M',
#     'id': '6ahyCttugbfTL3jhwglH4M',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730c5c703ee74a930041972248',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020c5c703ee74a930041972248',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510c5c703ee74a930041972248',
#       'width': 64}],
#     'name': 'You And The World',
#     'release_date': '2018-06-20',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:6ahyCttugbfTL3jhwglH4M'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LCRnJhAmGfgnYMkcOFvgu'},
#      'href': 'https://api.spotify.com/v1/artists/4LCRnJhAmGfgnYMkcOFvgu',
#      'id': '4LCRnJhAmGfgnYMkcOFvgu',
#      'name': 'TAMIREL',
#      'type': 'artist',
#      'uri': 'spotify:artist:4LCRnJhAmGfgnYMkcOFvgu'}],
#    'disc_number': 1,
#    'duration_ms': 244812,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZ5FN1888770'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05HGvfC2vLxTqAmiAOFkaX'},
#    'href': 'https://api.spotify.com/v1/tracks/05HGvfC2vLxTqAmiAOFkaX',
#    'id': '05HGvfC2vLxTqAmiAOFkaX',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Hesitant Soul',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c67a413179780997e76b654b93dac991632a5843?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:05HGvfC2vLxTqAmiAOFkaX'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xm7HBnIhim41jAYYbFR3x'},
#       'href': 'https://api.spotify.com/v1/artists/2xm7HBnIhim41jAYYbFR3x',
#       'id': '2xm7HBnIhim41jAYYbFR3x',
#       'name': 'حامد الضبعان',
#       'type': 'artist',
#       'uri': 'spotify:artist:2xm7HBnIhim41jAYYbFR3x'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0hNx9s1OSXSIgpHVrNhZOl'},
#     'href': 'https://api.spotify.com/v1/albums/0hNx9s1OSXSIgpHVrNhZOl',
#     'id': '0hNx9s1OSXSIgpHVrNhZOl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27382444ddcff6b9a6f95177c0b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0282444ddcff6b9a6f95177c0b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485182444ddcff6b9a6f95177c0b',
#       'width': 64}],
#     'name': 'طبق زيزي',
#     'release_date': '2018-03-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0hNx9s1OSXSIgpHVrNhZOl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xm7HBnIhim41jAYYbFR3x'},
#      'href': 'https://api.spotify.com/v1/artists/2xm7HBnIhim41jAYYbFR3x',
#      'id': '2xm7HBnIhim41jAYYbFR3x',
#      'name': 'حامد الضبعان',
#      'type': 'artist',
#      'uri': 'spotify:artist:2xm7HBnIhim41jAYYbFR3x'}],
#    'disc_number': 1,
#    'duration_ms': 140720,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAQ8S1615606'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05HLshWfNJwxR5VdW0JOQS'},
#    'href': 'https://api.spotify.com/v1/tracks/05HLshWfNJwxR5VdW0JOQS',
#    'id': '05HLshWfNJwxR5VdW0JOQS',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'طبق زيزي',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/87056b4ee7e32ad1e982b873f007ea3f1b1317d9?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05HLshWfNJwxR5VdW0JOQS'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0pzbsb0xhq4B5OxkHCbNgw'},
#       'href': 'https://api.spotify.com/v1/artists/0pzbsb0xhq4B5OxkHCbNgw',
#       'id': '0pzbsb0xhq4B5OxkHCbNgw',
#       'name': 'Ray Isaac',
#       'type': 'artist',
#       'uri': 'spotify:artist:0pzbsb0xhq4B5OxkHCbNgw'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4mYvwWPNIysfrtUcnFYYHD'},
#     'href': 'https://api.spotify.com/v1/albums/4mYvwWPNIysfrtUcnFYYHD',
#     'id': '4mYvwWPNIysfrtUcnFYYHD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d35e751403ccbb0faff965cc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d35e751403ccbb0faff965cc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d35e751403ccbb0faff965cc',
#       'width': 64}],
#     'name': 'Prove I Love Ya',
#     'release_date': '2018-01-17',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:4mYvwWPNIysfrtUcnFYYHD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0pzbsb0xhq4B5OxkHCbNgw'},
#      'href': 'https://api.spotify.com/v1/artists/0pzbsb0xhq4B5OxkHCbNgw',
#      'id': '0pzbsb0xhq4B5OxkHCbNgw',
#      'name': 'Ray Isaac',
#      'type': 'artist',
#      'uri': 'spotify:artist:0pzbsb0xhq4B5OxkHCbNgw'}],
#    'disc_number': 1,
#    'duration_ms': 255585,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZAPG1842662'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05HNaiPdbpmvyGbxM63MoC'},
#    'href': 'https://api.spotify.com/v1/tracks/05HNaiPdbpmvyGbxM63MoC',
#    'id': '05HNaiPdbpmvyGbxM63MoC',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Prove I Love Ya - Dance Remix',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/972e4677d5f2fb5cc183889ed85f35bd774a16ee?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:05HNaiPdbpmvyGbxM63MoC'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2pexGBYCYZadfQvlrmvjGt'},
#       'href': 'https://api.spotify.com/v1/artists/2pexGBYCYZadfQvlrmvjGt',
#       'id': '2pexGBYCYZadfQvlrmvjGt',
#       'name': 'Václav Neckář',
#       'type': 'artist',
#       'uri': 'spotify:artist:2pexGBYCYZadfQvlrmvjGt'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Gh9wqCK04Mk0dfmPgEsTZ'},
#     'href': 'https://api.spotify.com/v1/albums/3Gh9wqCK04Mk0dfmPgEsTZ',
#     'id': '3Gh9wqCK04Mk0dfmPgEsTZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f538ce9f888485843dbe7290',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f538ce9f888485843dbe7290',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f538ce9f888485843dbe7290',
#       'width': 64}],
#     'name': 'Já Ti Zabrnkám / Balady',
#     'release_date': '2018-10-19',
#     'release_date_precision': 'day',
#     'total_tracks': 38,
#     'type': 'album',
#     'uri': 'spotify:album:3Gh9wqCK04Mk0dfmPgEsTZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2pexGBYCYZadfQvlrmvjGt'},
#      'href': 'https://api.spotify.com/v1/artists/2pexGBYCYZadfQvlrmvjGt',
#      'id': '2pexGBYCYZadfQvlrmvjGt',
#      'name': 'Václav Neckář',
#      'type': 'artist',
#      'uri': 'spotify:artist:2pexGBYCYZadfQvlrmvjGt'}],
#    'disc_number': 1,
#    'duration_ms': 166373,
#    'explicit': False,
#    'external_ids': {'isrc': 'CZA166700174'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05HNkoFdD8Ubm68y3R7cOg'},
#    'href': 'https://api.spotify.com/v1/tracks/05HNkoFdD8Ubm68y3R7cOg',
#    'id': '05HNkoFdD8Ubm68y3R7cOg',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cena Za Místo Mezi Lidmi',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1d9a6e1650d8df9bbc27ecd25b463d89c4a6048a?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:05HNkoFdD8Ubm68y3R7cOg'},
#   {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6OaaoHKpCWB3lK01LjIuCB'},
#     'href': 'https://api.spotify.com/v1/albums/6OaaoHKpCWB3lK01LjIuCB',
#     'id': '6OaaoHKpCWB3lK01LjIuCB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733a38511bd28e986623f52df9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023a38511bd28e986623f52df9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513a38511bd28e986623f52df9',
#       'width': 64}],
#     'name': 'Melodii Pentru Tine',
#     'release_date': '2018-06-25',
# ...
#     'uri': 'spotify:album:5GApykcAb2yqb5uUSzNAOS'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/39ePAp05xC1loWbb7bF46b'},
#      'href': 'https://api.spotify.com/v1/artists/39ePAp05xC1loWbb7bF46b',
#      'id': '39ePAp05xC1loWbb7bF46b',
#      'name': 'Thomas Brezina',
#      'type': 'artist',
#      'uri': 'spotify:artist:39ePAp05xC1loWbb7bF46b'}],
#    'disc_number': 1,
#    'duration_ms': 125263,
#    'explicit': False,
#    'external_ids': {'isrc': 'ATB151800960'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05NEgUJNjawhLkYl9DpxJq'},
#    'href': 'https://api.spotify.com/v1/tracks/05NEgUJNjawhLkYl9DpxJq',
#    'id': '05NEgUJNjawhLkYl9DpxJq',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Knickerbocker4immer - Schatten der Zukunft - Kapitel 47, Teil 1',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/844bfd0677b2d9783fff57c66f07d5a65ad56123?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 136,
#    'type': 'track',
#    'uri': 'spotify:track:05NEgUJNjawhLkYl9DpxJq'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/242rf2m0v2nhWcSmZsBTT9'},
#       'href': 'https://api.spotify.com/v1/artists/242rf2m0v2nhWcSmZsBTT9',
#       'id': '242rf2m0v2nhWcSmZsBTT9',
#       'name': 'Dwarrowdelf',
#       'type': 'artist',
#       'uri': 'spotify:artist:242rf2m0v2nhWcSmZsBTT9'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2B89o5ilF5s1P3WQ4ExXpC'},
#     'href': 'https://api.spotify.com/v1/albums/2B89o5ilF5s1P3WQ4ExXpC',
#     'id': '2B89o5ilF5s1P3WQ4ExXpC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ffdb2886f14b93fa6603e523',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ffdb2886f14b93fa6603e523',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ffdb2886f14b93fa6603e523',
#       'width': 64}],
#     'name': 'Of Darkened Halls (Remaster)',
#     'release_date': '2018-10-04',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:2B89o5ilF5s1P3WQ4ExXpC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/242rf2m0v2nhWcSmZsBTT9'},
#      'href': 'https://api.spotify.com/v1/artists/242rf2m0v2nhWcSmZsBTT9',
#      'id': '242rf2m0v2nhWcSmZsBTT9',
#      'name': 'Dwarrowdelf',
#      'type': 'artist',
#      'uri': 'spotify:artist:242rf2m0v2nhWcSmZsBTT9'}],
#    'disc_number': 1,
#    'duration_ms': 514745,
#    'explicit': False,
#    'external_ids': {'isrc': 'USLZJ1866670'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05NaEt5Q2WnF5iYhetRS0P'},
#    'href': 'https://api.spotify.com/v1/tracks/05NaEt5Q2WnF5iYhetRS0P',
#    'id': '05NaEt5Q2WnF5iYhetRS0P',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Far Over the Misty Mountains Cold',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1bebe8c4bab2904fcc2655174b78ea62a0c484c7?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:05NaEt5Q2WnF5iYhetRS0P'},
#   {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/046fe1KmvOej9DXwc47ZSY'},
#     'href': 'https://api.spotify.com/v1/albums/046fe1KmvOej9DXwc47ZSY',
#     'id': '046fe1KmvOej9DXwc47ZSY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27319368458cd430def281f76cb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0219368458cd430def281f76cb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485119368458cd430def281f76cb',
#       'width': 64}],
#     'name': 'Tiếng Gọi Thanh Niên',
#     'release_date': '2018-09-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:046fe1KmvOej9DXwc47ZSY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'disc_number': 1,
#    'duration_ms': 211095,
#    'explicit': False,
#    'external_ids': {'isrc': 'VNA0M1831421'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05OGVUB5ps4okCxmgBdaYx'},
#    'href': 'https://api.spotify.com/v1/tracks/05OGVUB5ps4okCxmgBdaYx',
#    'id': '05OGVUB5ps4okCxmgBdaYx',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Tiến Về Hà Nội',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/48e1e2c6c1bdec8061ff56d4373fa215cc372d11?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:05OGVUB5ps4okCxmgBdaYx'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mbI2Vrn5ZIHEH1PzTrA4K'},
#       'href': 'https://api.spotify.com/v1/artists/1mbI2Vrn5ZIHEH1PzTrA4K',
#       'id': '1mbI2Vrn5ZIHEH1PzTrA4K',
#       'name': 'Werner Bekker',
#       'type': 'artist',
#       'uri': 'spotify:artist:1mbI2Vrn5ZIHEH1PzTrA4K'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2EufPaNX1n7byZm120Jfqx'},
#     'href': 'https://api.spotify.com/v1/albums/2EufPaNX1n7byZm120Jfqx',
#     'id': '2EufPaNX1n7byZm120Jfqx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dcb39ec5b49824f9fee3455e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dcb39ec5b49824f9fee3455e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dcb39ec5b49824f9fee3455e',
#       'width': 64}],
#     'name': 'Alive Again',
#     'release_date': '2018-03-09',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2EufPaNX1n7byZm120Jfqx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mbI2Vrn5ZIHEH1PzTrA4K'},
#      'href': 'https://api.spotify.com/v1/artists/1mbI2Vrn5ZIHEH1PzTrA4K',
#      'id': '1mbI2Vrn5ZIHEH1PzTrA4K',
#      'name': 'Werner Bekker',
#      'type': 'artist',
#      'uri': 'spotify:artist:1mbI2Vrn5ZIHEH1PzTrA4K'}],
#    'disc_number': 1,
#    'duration_ms': 191125,
#    'explicit': False,
#    'external_ids': {'isrc': 'USDHM1802769'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05PEnbEP1JXvsEhLG6Xazw'},
#    'href': 'https://api.spotify.com/v1/tracks/05PEnbEP1JXvsEhLG6Xazw',
#    'id': '05PEnbEP1JXvsEhLG6Xazw',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Alive Again',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a498abd4b649599038c2b164fc955ec3a1895bb0?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05PEnbEP1JXvsEhLG6Xazw'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qAwX8gXIQD5zZOTQiY9gm'},
#       'href': 'https://api.spotify.com/v1/artists/6qAwX8gXIQD5zZOTQiY9gm',
#       'id': '6qAwX8gXIQD5zZOTQiY9gm',
#       'name': 'Buddha Lounge',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qAwX8gXIQD5zZOTQiY9gm'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1OwdYxpa21iZMmCUmIGfuT'},
#     'href': 'https://api.spotify.com/v1/albums/1OwdYxpa21iZMmCUmIGfuT',
#     'id': '1OwdYxpa21iZMmCUmIGfuT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273de63e3eff264a2cfb429a7d1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02de63e3eff264a2cfb429a7d1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851de63e3eff264a2cfb429a7d1',
#       'width': 64}],
#     'name': 'Tibetan Buddhist Meditation',
#     'release_date': '2018-01-17',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:1OwdYxpa21iZMmCUmIGfuT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qAwX8gXIQD5zZOTQiY9gm'},
#      'href': 'https://api.spotify.com/v1/artists/6qAwX8gXIQD5zZOTQiY9gm',
#      'id': '6qAwX8gXIQD5zZOTQiY9gm',
#      'name': 'Buddha Lounge',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qAwX8gXIQD5zZOTQiY9gm'}],
#    'disc_number': 1,
#    'duration_ms': 225200,
#    'explicit': False,
#    'external_ids': {'isrc': 'PLS921610752'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05Q4eG4IQxOpAGvIrd7rV1'},
#    'href': 'https://api.spotify.com/v1/tracks/05Q4eG4IQxOpAGvIrd7rV1',
#    'id': '05Q4eG4IQxOpAGvIrd7rV1',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Zen Music',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fc311f4f084c3a027c85e4f7df86d0a7bb830f6c?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:05Q4eG4IQxOpAGvIrd7rV1'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vY7vJs5vjlXPnpCDm3Wvt'},
#       'href': 'https://api.spotify.com/v1/artists/0vY7vJs5vjlXPnpCDm3Wvt',
#       'id': '0vY7vJs5vjlXPnpCDm3Wvt',
#       'name': 'Cheb Titou',
#       'type': 'artist',
#       'uri': 'spotify:artist:0vY7vJs5vjlXPnpCDm3Wvt'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3MjphfkGt91kvGYCkHySXy'},
#     'href': 'https://api.spotify.com/v1/albums/3MjphfkGt91kvGYCkHySXy',
#     'id': '3MjphfkGt91kvGYCkHySXy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273112ecbff21f6396669acf3f7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02112ecbff21f6396669acf3f7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851112ecbff21f6396669acf3f7',
#       'width': 64}],
#     'name': 'Style 3roubi',
#     'release_date': '2018-12-20',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:3MjphfkGt91kvGYCkHySXy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vY7vJs5vjlXPnpCDm3Wvt'},
#      'href': 'https://api.spotify.com/v1/artists/0vY7vJs5vjlXPnpCDm3Wvt',
#      'id': '0vY7vJs5vjlXPnpCDm3Wvt',
#      'name': 'Cheb Titou',
#      'type': 'artist',
#      'uri': 'spotify:artist:0vY7vJs5vjlXPnpCDm3Wvt'}],
#    'disc_number': 1,
#    'duration_ms': 375506,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM7281878007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05QD8Rdk6wAY9Y7Gj5M8TW'},
#    'href': 'https://api.spotify.com/v1/tracks/05QD8Rdk6wAY9Y7Gj5M8TW',
#    'id': '05QD8Rdk6wAY9Y7Gj5M8TW',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ha lwalida',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a456918b91ba1abfaeae0500637d4eb5f8f15f51?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:05QD8Rdk6wAY9Y7Gj5M8TW'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5BsxIzYt6H2bLS3n8Tele7'},
#       'href': 'https://api.spotify.com/v1/artists/5BsxIzYt6H2bLS3n8Tele7',
#       'id': '5BsxIzYt6H2bLS3n8Tele7',
#       'name': 'R.2.R.S.',
#       'type': 'artist',
#       'uri': 'spotify:artist:5BsxIzYt6H2bLS3n8Tele7'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3alETDwm8xT9tanZUGMBbK'},
#     'href': 'https://api.spotify.com/v1/albums/3alETDwm8xT9tanZUGMBbK',
#     'id': '3alETDwm8xT9tanZUGMBbK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27355015d5f067831e4bb126ba1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0255015d5f067831e4bb126ba1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485155015d5f067831e4bb126ba1',
#       'width': 64}],
#     'name': 'Dieviete',
#     'release_date': '2018-08-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3alETDwm8xT9tanZUGMBbK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5BsxIzYt6H2bLS3n8Tele7'},
#      'href': 'https://api.spotify.com/v1/artists/5BsxIzYt6H2bLS3n8Tele7',
#      'id': '5BsxIzYt6H2bLS3n8Tele7',
#      'name': 'R.2.R.S.',
#      'type': 'artist',
#      'uri': 'spotify:artist:5BsxIzYt6H2bLS3n8Tele7'}],
#    'disc_number': 1,
#    'duration_ms': 199044,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZDA81887038'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05QLwwS6FYRzu0bpZqpySK'},
#    'href': 'https://api.spotify.com/v1/tracks/05QLwwS6FYRzu0bpZqpySK',
#    'id': '05QLwwS6FYRzu0bpZqpySK',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Dieviete',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/40e6c2a6d60c5747b187a9713f87d087e6130a98?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05QLwwS6FYRzu0bpZqpySK'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uym9GH8q6rqaGk25zellX'},
#       'href': 'https://api.spotify.com/v1/artists/6uym9GH8q6rqaGk25zellX',
#       'id': '6uym9GH8q6rqaGk25zellX',
#       'name': 'Ragga Gröndal',
#       'type': 'artist',
#       'uri': 'spotify:artist:6uym9GH8q6rqaGk25zellX'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/49ukWDh5xUc1mIsZYgEE0G'},
#     'href': 'https://api.spotify.com/v1/albums/49ukWDh5xUc1mIsZYgEE0G',
#     'id': '49ukWDh5xUc1mIsZYgEE0G',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731f50051c41ecb66edf164faa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021f50051c41ecb66edf164faa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511f50051c41ecb66edf164faa',
#       'width': 64}],
#     'name': 'Jörðin Mín',
#     'release_date': '2018-04-22',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:49ukWDh5xUc1mIsZYgEE0G'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uym9GH8q6rqaGk25zellX'},
#      'href': 'https://api.spotify.com/v1/artists/6uym9GH8q6rqaGk25zellX',
#      'id': '6uym9GH8q6rqaGk25zellX',
#      'name': 'Ragga Gröndal',
#      'type': 'artist',
#      'uri': 'spotify:artist:6uym9GH8q6rqaGk25zellX'}],
#    'disc_number': 1,
#    'duration_ms': 351764,
#    'explicit': False,
#    'external_ids': {'isrc': 'ISV441822702'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05QZ5AySyDrdPlgU1CDnJ1'},
#    'href': 'https://api.spotify.com/v1/tracks/05QZ5AySyDrdPlgU1CDnJ1',
#    'id': '05QZ5AySyDrdPlgU1CDnJ1',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Jörðin Mín',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a1bf05c8538365c76e69639dd26508b3672f5e6c?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05QZ5AySyDrdPlgU1CDnJ1'}],
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/search?query=year%3A2018+AND+tag%3Ahipster&type=track&market=US&offset=2000&limit=50',
#  'offset': 1950,
#  'previous': 'https://api.spotify.com/v1/search?query=year%3A2018+AND+tag%3Ahipster&type=track&market=US&offset=1900&limit=50',
#  'total': 100000}

# %%
#track_results['tracks']

# %%
# imports.
import pandas as pd

# create the tracks data frame.
df_tracks = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'track_id':track_id,'popularity':popularity})
# show the data frame shape.
print(df_tracks.shape)
# show the data frame with headers.
df_tracks.head()
# Out:
# (2000, 4)
#                    artist_name  ... popularity
# 0                 Luis Estrada  ...          4
# 1  Sabrina Is Not In This Chat  ...          4
# 2                 Luis Estrada  ...          4
# 3                  Leah Voysey  ...          4
# 4                Andrei Krylov  ...          4
#
# [5 rows x 4 columns]

# %%
# group entries by artist_name and track_name, check for duplicates.
grouped = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
print(grouped[grouped > 1].count())
df_tracks.drop_duplicates(subset=['artist_name','track_name'], inplace=True)
# Out:
# 46

# %%
# verify duplicates were dropped.
grouped_after_dropping = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
grouped_after_dropping[grouped_after_dropping > 1].count()
# Out:
# 0

# %%
# show basic info for tracks data.
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1954 entries, 0 to 1999
# Data columns (total 4 columns):
# artist_name    1954 non-null object
# track_name     1954 non-null object
# track_id       1954 non-null object
# popularity     1954 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 76.3+ KB

# %% [markdown]
# ### Track Audio Features Data.

# %%
# timeit library to measure the time needed to run this code.
start = timeit.default_timer()

# empty list, batchsize, counter for 'none' results.
rows = []
batchsize = 100
None_counter = 0

for i in range(0,len(df_tracks['track_id']),batchsize):
    batch = df_tracks['track_id'][i:i+batchsize]
    feature_results = sp.audio_features(batch)
    for i, t in enumerate(feature_results):
        if t == None:
            None_counter = None_counter + 1
        else:
            rows.append(t)
            
print('Number of tracks where no audio features were available:',None_counter)
stop = timeit.default_timer()
print ('Time to run this code (in seconds):',stop - start)
# Out:
# Number of tracks where no audio features were available: 0
# Time to run this code (in seconds): 3.0535056440003245

# %%
# create the audio features data frame.
df_audio_features = pd.DataFrame.from_dict(rows,orient='columns')
# show the shape of the data frame.
print(df_audio_features.shape)
# show the data frame with headers.
df_audio_features.head()
# Out:
# (1954, 18)
#    danceability  energy  ...  duration_ms  time_signature
# 0         0.688   0.826  ...       213600               4
# 1         0.522   0.744  ...       236151               4
# 2         0.785   0.923  ...       236743               4
# 3         0.576   0.650  ...       139605               4
# 4         0.528   0.150  ...       102940               3
#
# [5 rows x 18 columns]

# %%
# show basic info for audio features data.
df_audio_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1954 entries, 0 to 1953
# Data columns (total 18 columns):
# danceability        1954 non-null float64
# energy              1954 non-null float64
# key                 1954 non-null int64
# loudness            1954 non-null float64
# mode                1954 non-null int64
# speechiness         1954 non-null float64
# acousticness        1954 non-null float64
# instrumentalness    1954 non-null float64
# liveness            1954 non-null float64
# valence             1954 non-null float64
# tempo               1954 non-null float64
# type                1954 non-null object
# id                  1954 non-null object
# uri                 1954 non-null object
# track_href          1954 non-null object
# analysis_url        1954 non-null object
# duration_ms         1954 non-null int64
# time_signature      1954 non-null int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 274.9+ KB

# %%
# rename id column to merge with tracks data frame.
df_audio_features.rename(columns={'id': 'track_id'}, inplace=True)

# %%
# drop useless columns.
columns_to_drop = ['analysis_url','track_href','type','uri']
df_audio_features.drop(columns_to_drop, axis=1,inplace=True)
# show the data frame shape.
print(df_audio_features.shape)
# Out:
# (1954, 14)

# %%
# merge both dataframes with inner method to keep track IDs present in both data frames.
df = pd.merge(df_tracks,df_audio_features,on='track_id',how='inner')
print(df.shape)
df.head()
# Out:
# (1954, 17)
#                    artist_name  ... time_signature
# 0                 Luis Estrada  ...              4
# 1  Sabrina Is Not In This Chat  ...              4
# 2                 Luis Estrada  ...              4
# 3                  Leah Voysey  ...              4
# 4                Andrei Krylov  ...              3
#
# [5 rows x 17 columns]

# %% [markdown]
# ### Final.

# %%
# check for NA values.
df.isna().sum()
# Out:
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
#print(df.shape)
df.head()
# Out:
#                    artist_name  ... time_signature
# 0                 Luis Estrada  ...              4
# 1  Sabrina Is Not In This Chat  ...              4
# 2                 Luis Estrada  ...              4
# 3                  Leah Voysey  ...              4
# 4                Andrei Krylov  ...              3
#
# [5 rows x 17 columns]

# %% [markdown]
# ### Create a CSV file.

# %%
from google.colab import files
df.to_csv('SpotifyTracks_2018hipster.csv')
files.download('SpotifyTracks_2018hipster.csv')
