# %% [markdown]
# # Collecting Data from the Spotify Web API using Spotipy
#
# ## About the Spotipy Library:
#
# From the [official Spotipy docs](https://spotipy.readthedocs.io/en/latest/):
# >"Spotipy is a lightweight Python library for the Spotify Web API. With Spotipy you get full access to all of the music data provided by the Spotify platform."
#
#
# ## About using the Spotify Web API:
#
# Spotify offers a number of [API endpoints](https://beta.developer.spotify.com/documentation/web-api/reference/) to access the Spotify data. In this notebook, I used the following:
#
# - [search endpoint](https://beta.developer.spotify.com/documentation/web-api/reference/search/search/) to get the track IDs
# - [audio features endpoint](https://beta.developer.spotify.com/documentation/web-api/reference/tracks/get-several-audio-features/) to get the corresponding audio features.

# %% [markdown]
# ### Set Spotipy Credentials.

# %%
# pip install spotipy.
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.6/dist-packages (2.9.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from spotipy) (1.12.0)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from spotipy) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->spotipy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->spotipy) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->spotipy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->spotipy) (1.24.3)

# %%
# imports.
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# spotify credentials.
cid = '51c2d40e57e74fbb852374c80b4f0054'
secret = '8b0cafe24a7c45818f2b01f12fec13e5'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Song Tracks Data.

# %%
# imports.
import timeit
import time

# timeit library to measure the time needed to run this code.
start = timeit.default_timer()

# empty lists where the results are going to be stored
artist_name = []
track_name = []
popularity = []
track_id = []

for i in range(0,2000,50):
    # search by year.
    #track_results = sp.search(q='year:2020', limit=50, offset=i, market='EU')
    # search by genre.
    #track_results = sp.search(q='genre:dance', limit=50, offset=i, market='US')
    # search year and genre.
    track_results = sp.search(q='year:2018 AND tag:hipster', limit=50, offset=i, market='US')

    #time.sleep(0.50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        
stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)
track_results['tracks']
# Out:
# Time to run this code (in seconds): 11.404927899999999
# {'href': 'https://api.spotify.com/v1/search?query=year%3A2018+AND+tag%3Ahipster&type=track&market=US&offset=1950&limit=50',
#  'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dJ05O9EOtFVROVfEEHBBc'},
#       'href': 'https://api.spotify.com/v1/artists/7dJ05O9EOtFVROVfEEHBBc',
#       'id': '7dJ05O9EOtFVROVfEEHBBc',
#       'name': 'Lullabies for Deep Meditation',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dJ05O9EOtFVROVfEEHBBc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xj0jN2EifogsCRT1f91Zy'},
#       'href': 'https://api.spotify.com/v1/artists/5xj0jN2EifogsCRT1f91Zy',
#       'id': '5xj0jN2EifogsCRT1f91Zy',
#       'name': 'Zen Meditation and Natural White Noise and New Age Deep Massage',
#       'type': 'artist',
#       'uri': 'spotify:artist:5xj0jN2EifogsCRT1f91Zy'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MSV8ibxF4Tn6eyDSUjFuY'},
#       'href': 'https://api.spotify.com/v1/artists/3MSV8ibxF4Tn6eyDSUjFuY',
#       'id': '3MSV8ibxF4Tn6eyDSUjFuY',
#       'name': 'Relajación',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MSV8ibxF4Tn6eyDSUjFuY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0M9A3SttSac3C0Zpr5VdS2'},
#     'href': 'https://api.spotify.com/v1/albums/0M9A3SttSac3C0Zpr5VdS2',
#     'id': '0M9A3SttSac3C0Zpr5VdS2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273737c33da3b475ec2cf372bc5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02737c33da3b475ec2cf372bc5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851737c33da3b475ec2cf372bc5',
#       'width': 64}],
#     'name': 'Ultimate Relaxative Yoga',
#     'release_date': '2018-04-01',
#     'release_date_precision': 'day',
#     'total_tracks': 100,
#     'type': 'album',
#     'uri': 'spotify:album:0M9A3SttSac3C0Zpr5VdS2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fapdkOkECRqWp0dr8VcL4'},
#      'href': 'https://api.spotify.com/v1/artists/3fapdkOkECRqWp0dr8VcL4',
#      'id': '3fapdkOkECRqWp0dr8VcL4',
#      'name': 'Meditation Music',
#      'type': 'artist',
#      'uri': 'spotify:artist:3fapdkOkECRqWp0dr8VcL4'}],
#    'disc_number': 1,
#    'duration_ms': 98302,
#    'explicit': False,
#    'external_ids': {'isrc': 'SE5WR1810089'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/04zD6IzWs2E5vwteIM4Jgf'},
#    'href': 'https://api.spotify.com/v1/tracks/04zD6IzWs2E5vwteIM4Jgf',
#    'id': '04zD6IzWs2E5vwteIM4Jgf',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Teachers Song',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f73a0b328b04fb3646a6df13208816db0df083ec?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 83,
#    'type': 'track',
#    'uri': 'spotify:track:04zD6IzWs2E5vwteIM4Jgf'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65SDvaflPidRzW7V2fTiQ1'},
#       'href': 'https://api.spotify.com/v1/artists/65SDvaflPidRzW7V2fTiQ1',
#       'id': '65SDvaflPidRzW7V2fTiQ1',
#       'name': 'Opoštáris',
#       'type': 'artist',
#       'uri': 'spotify:artist:65SDvaflPidRzW7V2fTiQ1'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2BbKaI27CEMvrTSv0wD51i'},
#     'href': 'https://api.spotify.com/v1/albums/2BbKaI27CEMvrTSv0wD51i',
#     'id': '2BbKaI27CEMvrTSv0wD51i',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27360b1913be47e93555d5fc016',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0260b1913be47e93555d5fc016',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485160b1913be47e93555d5fc016',
#       'width': 64}],
#     'name': 'Sa Oplatí',
#     'release_date': '2018-06-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2BbKaI27CEMvrTSv0wD51i'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65SDvaflPidRzW7V2fTiQ1'},
#      'href': 'https://api.spotify.com/v1/artists/65SDvaflPidRzW7V2fTiQ1',
#      'id': '65SDvaflPidRzW7V2fTiQ1',
#      'name': 'Opoštáris',
#      'type': 'artist',
#      'uri': 'spotify:artist:65SDvaflPidRzW7V2fTiQ1'}],
#    'disc_number': 1,
#    'duration_ms': 234631,
#    'explicit': True,
#    'external_ids': {'isrc': 'TCADR1865990'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0509BO1bQQsybxwQh7TuMy'},
#    'href': 'https://api.spotify.com/v1/tracks/0509BO1bQQsybxwQh7TuMy',
#    'id': '0509BO1bQQsybxwQh7TuMy',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Sa Oplatí',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8752dfb127b39bc66c06e9ca265caf421e63f7d4?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0509BO1bQQsybxwQh7TuMy'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VMdO9QeJs217hioSA0HUN'},
#       'href': 'https://api.spotify.com/v1/artists/5VMdO9QeJs217hioSA0HUN',
#       'id': '5VMdO9QeJs217hioSA0HUN',
#       'name': 'NUVO',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VMdO9QeJs217hioSA0HUN'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2pTJnWEM78FoLuxAhImg7W'},
#     'href': 'https://api.spotify.com/v1/albums/2pTJnWEM78FoLuxAhImg7W',
#     'id': '2pTJnWEM78FoLuxAhImg7W',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c88ec9f49b4b3408a9837988',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c88ec9f49b4b3408a9837988',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c88ec9f49b4b3408a9837988',
#       'width': 64}],
#     'name': 'Laiks ir asinīs',
#     'release_date': '2018-05-07',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:2pTJnWEM78FoLuxAhImg7W'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VMdO9QeJs217hioSA0HUN'},
#      'href': 'https://api.spotify.com/v1/artists/5VMdO9QeJs217hioSA0HUN',
#      'id': '5VMdO9QeJs217hioSA0HUN',
#      'name': 'NUVO',
#      'type': 'artist',
#      'uri': 'spotify:artist:5VMdO9QeJs217hioSA0HUN'}],
#    'disc_number': 1,
#    'duration_ms': 194628,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZB4J1809686'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/050iXY4daoR6TZdrt7SIli'},
#    'href': 'https://api.spotify.com/v1/tracks/050iXY4daoR6TZdrt7SIli',
#    'id': '050iXY4daoR6TZdrt7SIli',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Laiks ir asinīs',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/acdce0f775ca9f28a1c3d948efd126e8fc596b35?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:050iXY4daoR6TZdrt7SIli'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5d3PvVkiDRWQN7N2AskQJt'},
#       'href': 'https://api.spotify.com/v1/artists/5d3PvVkiDRWQN7N2AskQJt',
#       'id': '5d3PvVkiDRWQN7N2AskQJt',
#       'name': 'AZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:5d3PvVkiDRWQN7N2AskQJt'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5e7LRADuU8gQv98QzkilH3'},
#     'href': 'https://api.spotify.com/v1/albums/5e7LRADuU8gQv98QzkilH3',
#     'id': '5e7LRADuU8gQv98QzkilH3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a7b31141c05f72dce8848762',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a7b31141c05f72dce8848762',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a7b31141c05f72dce8848762',
#       'width': 64}],
#     'name': 'Tafsut n Usays',
#     'release_date': '2018-06-16',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5e7LRADuU8gQv98QzkilH3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5d3PvVkiDRWQN7N2AskQJt'},
#      'href': 'https://api.spotify.com/v1/artists/5d3PvVkiDRWQN7N2AskQJt',
#      'id': '5d3PvVkiDRWQN7N2AskQJt',
#      'name': 'AZA',
#      'type': 'artist',
#      'uri': 'spotify:artist:5d3PvVkiDRWQN7N2AskQJt'}],
#    'disc_number': 1,
#    'duration_ms': 305446,
#    'explicit': False,
#    'external_ids': {'isrc': 'ushm21860809'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/050uE6JbPdSVNILGHQmUKA'},
#    'href': 'https://api.spotify.com/v1/tracks/050uE6JbPdSVNILGHQmUKA',
#    'id': '050uE6JbPdSVNILGHQmUKA',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Imzzi',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ce5c3851d76aabf0303c1dc98c5a728e14c93670?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:050uE6JbPdSVNILGHQmUKA'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lFDQOEK5OwsyPXb1aWJzY'},
#       'href': 'https://api.spotify.com/v1/artists/0lFDQOEK5OwsyPXb1aWJzY',
#       'id': '0lFDQOEK5OwsyPXb1aWJzY',
#       'name': 'Little Baby Bum Nursery Rhyme Friends',
#       'type': 'artist',
#       'uri': 'spotify:artist:0lFDQOEK5OwsyPXb1aWJzY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5hP3Dah0lGJhnrccJiLMm9'},
#     'href': 'https://api.spotify.com/v1/albums/5hP3Dah0lGJhnrccJiLMm9',
#     'id': '5hP3Dah0lGJhnrccJiLMm9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273355b55cfb5a0790de3f74df0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02355b55cfb5a0790de3f74df0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851355b55cfb5a0790de3f74df0',
#       'width': 64}],
#     'name': 'On a Bike',
#     'release_date': '2018-07-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5hP3Dah0lGJhnrccJiLMm9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lFDQOEK5OwsyPXb1aWJzY'},
#      'href': 'https://api.spotify.com/v1/artists/0lFDQOEK5OwsyPXb1aWJzY',
#      'id': '0lFDQOEK5OwsyPXb1aWJzY',
#      'name': 'Little Baby Bum Nursery Rhyme Friends',
#      'type': 'artist',
#      'uri': 'spotify:artist:0lFDQOEK5OwsyPXb1aWJzY'}],
#    'disc_number': 1,
#    'duration_ms': 90500,
#    'explicit': False,
#    'external_ids': {'isrc': 'UKP3G1800524'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/051Zqqk7CUouKpVr0qEkKz'},
#    'href': 'https://api.spotify.com/v1/tracks/051Zqqk7CUouKpVr0qEkKz',
#    'id': '051Zqqk7CUouKpVr0qEkKz',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'On a Bike',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/aa74680c99950ea2a7adc83af82e8d760fed6b31?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:051Zqqk7CUouKpVr0qEkKz'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wxRni5Np1zDmIAftOps4V'},
#       'href': 'https://api.spotify.com/v1/artists/0wxRni5Np1zDmIAftOps4V',
#       'id': '0wxRni5Np1zDmIAftOps4V',
#       'name': 'Shen Bo',
#       'type': 'artist',
#       'uri': 'spotify:artist:0wxRni5Np1zDmIAftOps4V'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4h5UozRBPLWYdobA9XIrQP'},
#     'href': 'https://api.spotify.com/v1/albums/4h5UozRBPLWYdobA9XIrQP',
#     'id': '4h5UozRBPLWYdobA9XIrQP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ed07d99a2f1b2e70b19fa346',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ed07d99a2f1b2e70b19fa346',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ed07d99a2f1b2e70b19fa346',
#       'width': 64}],
#     'name': '冬天里的情歌',
#     'release_date': '2018-07-13',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4h5UozRBPLWYdobA9XIrQP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wxRni5Np1zDmIAftOps4V'},
#      'href': 'https://api.spotify.com/v1/artists/0wxRni5Np1zDmIAftOps4V',
#      'id': '0wxRni5Np1zDmIAftOps4V',
#      'name': 'Shen Bo',
#      'type': 'artist',
#      'uri': 'spotify:artist:0wxRni5Np1zDmIAftOps4V'}],
#    'disc_number': 1,
#    'duration_ms': 203494,
#    'explicit': False,
#    'external_ids': {'isrc': 'HK-C37-17-02580'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0522BnnvhHDnIpXIuWIGcS'},
#    'href': 'https://api.spotify.com/v1/tracks/0522BnnvhHDnIpXIuWIGcS',
#    'id': '0522BnnvhHDnIpXIuWIGcS',
#    'is_local': False,
#    'is_playable': True,
#    'name': '刚好遇见你',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/18424b4e4b0202936fcc073fb0af5bcdeb3b1a5e?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0522BnnvhHDnIpXIuWIGcS'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62ghjNskQdvtOuLX1fXEMX'},
#       'href': 'https://api.spotify.com/v1/artists/62ghjNskQdvtOuLX1fXEMX',
#       'id': '62ghjNskQdvtOuLX1fXEMX',
#       'name': 'ภูมิจิต',
#       'type': 'artist',
#       'uri': 'spotify:artist:62ghjNskQdvtOuLX1fXEMX'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6CC5jREuZ3xPoeOw7XPG1h'},
#     'href': 'https://api.spotify.com/v1/albums/6CC5jREuZ3xPoeOw7XPG1h',
#     'id': '6CC5jREuZ3xPoeOw7XPG1h',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bd34a3bd8457e6099a992875',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bd34a3bd8457e6099a992875',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bd34a3bd8457e6099a992875',
#       'width': 64}],
#     'name': 'Found And Lost',
#     'release_date': '2018-10-26',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6CC5jREuZ3xPoeOw7XPG1h'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62ghjNskQdvtOuLX1fXEMX'},
#      'href': 'https://api.spotify.com/v1/artists/62ghjNskQdvtOuLX1fXEMX',
#      'id': '62ghjNskQdvtOuLX1fXEMX',
#      'name': 'ภูมิจิต',
#      'type': 'artist',
#      'uri': 'spotify:artist:62ghjNskQdvtOuLX1fXEMX'}],
#    'disc_number': 1,
#    'duration_ms': 291146,
#    'explicit': False,
#    'external_ids': {'isrc': 'THG011800753'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0525R86aALqKGQ3KzqbU3k'},
#    'href': 'https://api.spotify.com/v1/tracks/0525R86aALqKGQ3KzqbU3k',
#    'id': '0525R86aALqKGQ3KzqbU3k',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'ไม่เป็นดั่งฝัน',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/aa3eea5ab2c861b1964899bd019a4e8f0c41a699?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:0525R86aALqKGQ3KzqbU3k'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6D836zWViEHhjiY1QgAH8R'},
#       'href': 'https://api.spotify.com/v1/artists/6D836zWViEHhjiY1QgAH8R',
#       'id': '6D836zWViEHhjiY1QgAH8R',
#       'name': 'Will Blunderfield',
#       'type': 'artist',
#       'uri': 'spotify:artist:6D836zWViEHhjiY1QgAH8R'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1XEkc9MErrn9SHYuxM1C7g'},
#     'href': 'https://api.spotify.com/v1/albums/1XEkc9MErrn9SHYuxM1C7g',
#     'id': '1XEkc9MErrn9SHYuxM1C7g',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a1ea3ee3a677845cca986cb2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a1ea3ee3a677845cca986cb2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a1ea3ee3a677845cca986cb2',
#       'width': 64}],
#     'name': 'Wild Horses (Special Edition)',
#     'release_date': '2018-05-09',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1XEkc9MErrn9SHYuxM1C7g'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6D836zWViEHhjiY1QgAH8R'},
#      'href': 'https://api.spotify.com/v1/artists/6D836zWViEHhjiY1QgAH8R',
#      'id': '6D836zWViEHhjiY1QgAH8R',
#      'name': 'Will Blunderfield',
#      'type': 'artist',
#      'uri': 'spotify:artist:6D836zWViEHhjiY1QgAH8R'}],
#    'disc_number': 1,
#    'duration_ms': 279422,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAI371716288'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/052BbEEoKYHXSPZQ6ztgxu'},
#    'href': 'https://api.spotify.com/v1/tracks/052BbEEoKYHXSPZQ6ztgxu',
#    'id': '052BbEEoKYHXSPZQ6ztgxu',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'You Are More',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/87584f2b415b82387d6b36d32aadb390ab859e17?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:052BbEEoKYHXSPZQ6ztgxu'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q2TreW3Bz578GwbWqgIVI'},
#       'href': 'https://api.spotify.com/v1/artists/6Q2TreW3Bz578GwbWqgIVI',
#       'id': '6Q2TreW3Bz578GwbWqgIVI',
#       'name': 'Dady Myk',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Q2TreW3Bz578GwbWqgIVI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3j3Mh0LHBO3U5K1pi4T5sf'},
#     'href': 'https://api.spotify.com/v1/albums/3j3Mh0LHBO3U5K1pi4T5sf',
#     'id': '3j3Mh0LHBO3U5K1pi4T5sf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736654d0d58dcc88b6d7d38c70',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026654d0d58dcc88b6d7d38c70',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516654d0d58dcc88b6d7d38c70',
#       'width': 64}],
#     'name': 'Partition céleste',
#     'release_date': '2018-12-23',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:3j3Mh0LHBO3U5K1pi4T5sf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q2TreW3Bz578GwbWqgIVI'},
#      'href': 'https://api.spotify.com/v1/artists/6Q2TreW3Bz578GwbWqgIVI',
#      'id': '6Q2TreW3Bz578GwbWqgIVI',
#      'name': 'Dady Myk',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Q2TreW3Bz578GwbWqgIVI'}],
#    'disc_number': 1,
#    'duration_ms': 280003,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCADY1836427'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/052PBI0l9xsnoM4i6ZfGLA'},
#    'href': 'https://api.spotify.com/v1/tracks/052PBI0l9xsnoM4i6ZfGLA',
#    'id': '052PBI0l9xsnoM4i6ZfGLA',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Partition céleste',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f396b03d01f511e12c2e4f4fa15b244e3886e3e1?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:052PBI0l9xsnoM4i6ZfGLA'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gbpaLph03laDVxV9LCWeY'},
#       'href': 'https://api.spotify.com/v1/artists/4gbpaLph03laDVxV9LCWeY',
#       'id': '4gbpaLph03laDVxV9LCWeY',
#       'name': 'Группа большего спокойствия',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gbpaLph03laDVxV9LCWeY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4t0nVy2C0OuDSd85fgAXlk'},
#     'href': 'https://api.spotify.com/v1/albums/4t0nVy2C0OuDSd85fgAXlk',
#     'id': '4t0nVy2C0OuDSd85fgAXlk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739ffbc066cc79a3fe47e01515',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029ffbc066cc79a3fe47e01515',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519ffbc066cc79a3fe47e01515',
#       'width': 64}],
#     'name': 'Детский глубокий сон (30 Мирные инструментальные песни для сна, Лечение бессонницы у новорожденных)',
#     'release_date': '2018-01-18',
#     'release_date_precision': 'day',
#     'total_tracks': 30,
#     'type': 'album',
#     'uri': 'spotify:album:4t0nVy2C0OuDSd85fgAXlk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gbpaLph03laDVxV9LCWeY'},
#      'href': 'https://api.spotify.com/v1/artists/4gbpaLph03laDVxV9LCWeY',
#      'id': '4gbpaLph03laDVxV9LCWeY',
#      'name': 'Группа большего спокойствия',
#      'type': 'artist',
#      'uri': 'spotify:artist:4gbpaLph03laDVxV9LCWeY'}],
#    'disc_number': 1,
#    'duration_ms': 316897,
#    'explicit': False,
#    'external_ids': {'isrc': 'PLS921654634'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/052lhyeB64fGybNf9FFoX8'},
#    'href': 'https://api.spotify.com/v1/tracks/052lhyeB64fGybNf9FFoX8',
#    'id': '052lhyeB64fGybNf9FFoX8',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Лечебный массаж',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/796a7e34215c1d9ea961f0cb07e82fb2b6365504?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:052lhyeB64fGybNf9FFoX8'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TpB7ThFbkpLmIGvYWeqWm'},
#       'href': 'https://api.spotify.com/v1/artists/3TpB7ThFbkpLmIGvYWeqWm',
#       'id': '3TpB7ThFbkpLmIGvYWeqWm',
#       'name': 'Kronwildkrainer',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TpB7ThFbkpLmIGvYWeqWm'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4qtt4zxNqqC3Y8hTYqZRcw'},
#     'href': 'https://api.spotify.com/v1/albums/4qtt4zxNqqC3Y8hTYqZRcw',
#     'id': '4qtt4zxNqqC3Y8hTYqZRcw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739852b856af3dbe61cf253d0c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029852b856af3dbe61cf253d0c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519852b856af3dbe61cf253d0c',
#       'width': 64}],
#     'name': 'Musik, ein Elixier',
#     'release_date': '2018-03-02',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:4qtt4zxNqqC3Y8hTYqZRcw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TpB7ThFbkpLmIGvYWeqWm'},
#      'href': 'https://api.spotify.com/v1/artists/3TpB7ThFbkpLmIGvYWeqWm',
#      'id': '3TpB7ThFbkpLmIGvYWeqWm',
#      'name': 'Kronwildkrainer',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TpB7ThFbkpLmIGvYWeqWm'}],
#    'disc_number': 1,
#    'duration_ms': 158386,
#    'explicit': False,
#    'external_ids': {'isrc': 'ATH931850608'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/052qlBenRuaC5AceBbd0ez'},
#    'href': 'https://api.spotify.com/v1/tracks/052qlBenRuaC5AceBbd0ez',
#    'id': '052qlBenRuaC5AceBbd0ez',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Durch den grünen Hain',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/bae8a207e6387c354960c37ae302df806ea4da1c?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:052qlBenRuaC5AceBbd0ez'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMN6fOJ9EF6cUcd9pv7hE'},
#       'href': 'https://api.spotify.com/v1/artists/2EMN6fOJ9EF6cUcd9pv7hE',
#       'id': '2EMN6fOJ9EF6cUcd9pv7hE',
#       'name': 'Semantik',
#       'type': 'artist',
#       'uri': 'spotify:artist:2EMN6fOJ9EF6cUcd9pv7hE'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2fvsKxxbx2DrSHr51Cy49K'},
#     'href': 'https://api.spotify.com/v1/albums/2fvsKxxbx2DrSHr51Cy49K',
#     'id': '2fvsKxxbx2DrSHr51Cy49K',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737c67f84f248afcbd5daa845b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027c67f84f248afcbd5daa845b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517c67f84f248afcbd5daa845b',
#       'width': 64}],
#     'name': 'Sonnhalde',
#     'release_date': '2018-02-23',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:2fvsKxxbx2DrSHr51Cy49K'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMN6fOJ9EF6cUcd9pv7hE'},
#      'href': 'https://api.spotify.com/v1/artists/2EMN6fOJ9EF6cUcd9pv7hE',
#      'id': '2EMN6fOJ9EF6cUcd9pv7hE',
#      'name': 'Semantik',
#      'type': 'artist',
#      'uri': 'spotify:artist:2EMN6fOJ9EF6cUcd9pv7hE'}],
#    'disc_number': 1,
#    'duration_ms': 204679,
#    'explicit': False,
#    'external_ids': {'isrc': 'CH6540898028'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/052u5X3XbH938yun3pQZni'},
#    'href': 'https://api.spotify.com/v1/tracks/052u5X3XbH938yun3pQZni',
#    'id': '052u5X3XbH938yun3pQZni',
#    'is_local': False,
#    'is_playable': True,
#    'name': '4/4',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c3c2171ca09748fdc6b1dc71d033fb67650b4889?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:052u5X3XbH938yun3pQZni'},
#   {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/50zSbeRzoxo1YXl0z5iYMO'},
#     'href': 'https://api.spotify.com/v1/albums/50zSbeRzoxo1YXl0z5iYMO',
#     'id': '50zSbeRzoxo1YXl0z5iYMO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737a126ccc51c69821e5cae4f4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027a126ccc51c69821e5cae4f4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517a126ccc51c69821e5cae4f4',
#       'width': 64}],
#     'name': 'Mezi Hvězdami (Písničky TvMiniUni 3)',
#     'release_date': '2018-04-20',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:50zSbeRzoxo1YXl0z5iYMO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2pQJyBmoLjRouM3bg8doKu'},
#      'href': 'https://api.spotify.com/v1/artists/2pQJyBmoLjRouM3bg8doKu',
#      'id': '2pQJyBmoLjRouM3bg8doKu',
#      'name': 'XINDL X',
#      'type': 'artist',
#      'uri': 'spotify:artist:2pQJyBmoLjRouM3bg8doKu'}],
#    'disc_number': 1,
#    'duration_ms': 126680,
#    'explicit': False,
#    'external_ids': {'isrc': 'CZM021800021'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/052uNsB8zamewDFUOSSfEv'},
#    'href': 'https://api.spotify.com/v1/tracks/052uNsB8zamewDFUOSSfEv',
#    'id': '052uNsB8zamewDFUOSSfEv',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ukolébavka, Která Se Vám Jen Zdá',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/99f28317f693a1b7d99342cfd9a08dce8b746c40?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 21,
#    'type': 'track',
#    'uri': 'spotify:track:052uNsB8zamewDFUOSSfEv'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tvLovBlbaYyzUFeBgXRFW'},
#       'href': 'https://api.spotify.com/v1/artists/2tvLovBlbaYyzUFeBgXRFW',
#       'id': '2tvLovBlbaYyzUFeBgXRFW',
#       'name': 'Giang Tử',
#       'type': 'artist',
#       'uri': 'spotify:artist:2tvLovBlbaYyzUFeBgXRFW'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/43Xl9C2IkWVzc0BBumsasv'},
#     'href': 'https://api.spotify.com/v1/albums/43Xl9C2IkWVzc0BBumsasv',
#     'id': '43Xl9C2IkWVzc0BBumsasv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27311a8d3f3dc72d0b4e2391071',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0211a8d3f3dc72d0b4e2391071',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485111a8d3f3dc72d0b4e2391071',
#       'width': 64}],
#     'name': 'Qua Ngõ Nhà Em',
#     'release_date': '2018-08-30',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:43Xl9C2IkWVzc0BBumsasv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tvLovBlbaYyzUFeBgXRFW'},
#      'href': 'https://api.spotify.com/v1/artists/2tvLovBlbaYyzUFeBgXRFW',
#      'id': '2tvLovBlbaYyzUFeBgXRFW',
#      'name': 'Giang Tử',
#      'type': 'artist',
#      'uri': 'spotify:artist:2tvLovBlbaYyzUFeBgXRFW'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2P7WrPkRtQLLJY5KPOmDt3'},
#      'href': 'https://api.spotify.com/v1/artists/2P7WrPkRtQLLJY5KPOmDt3',
#      'id': '2P7WrPkRtQLLJY5KPOmDt3',
#      'name': 'Phương Dung',
#      'type': 'artist',
#      'uri': 'spotify:artist:2P7WrPkRtQLLJY5KPOmDt3'}],
#    'disc_number': 1,
#    'duration_ms': 318014,
#    'explicit': False,
#    'external_ids': {'isrc': 'VNA0M1830037'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/053bOfZ43Hs2wD14G5xdnb'},
#    'href': 'https://api.spotify.com/v1/tracks/053bOfZ43Hs2wD14G5xdnb',
#    'id': '053bOfZ43Hs2wD14G5xdnb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ngoéo Tay Nhau Thề',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c08e5a559ea1c1b53b812bf05e65bafc9842bf9b?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:053bOfZ43Hs2wD14G5xdnb'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lKJlCYD5WsrVWRthNH5lr'},
#       'href': 'https://api.spotify.com/v1/artists/6lKJlCYD5WsrVWRthNH5lr',
#       'id': '6lKJlCYD5WsrVWRthNH5lr',
#       'name': 'Sugey Holguin',
#       'type': 'artist',
#       'uri': 'spotify:artist:6lKJlCYD5WsrVWRthNH5lr'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6CfvX2ypxnfAivfx7tj23E'},
#     'href': 'https://api.spotify.com/v1/albums/6CfvX2ypxnfAivfx7tj23E',
#     'id': '6CfvX2ypxnfAivfx7tj23E',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e4acce2c3392fe9636576dd6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e4acce2c3392fe9636576dd6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e4acce2c3392fe9636576dd6',
#       'width': 64}],
#     'name': 'Para Adorarte',
#     'release_date': '2018-11-30',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:6CfvX2ypxnfAivfx7tj23E'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lKJlCYD5WsrVWRthNH5lr'},
#      'href': 'https://api.spotify.com/v1/artists/6lKJlCYD5WsrVWRthNH5lr',
#      'id': '6lKJlCYD5WsrVWRthNH5lr',
#      'name': 'Sugey Holguin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6lKJlCYD5WsrVWRthNH5lr'}],
#    'disc_number': 1,
#    'duration_ms': 247661,
#    'explicit': False,
#    'external_ids': {'isrc': 'USDHM1827056'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/053cszYX7LNud5wU0n7Vyu'},
#    'href': 'https://api.spotify.com/v1/tracks/053cszYX7LNud5wU0n7Vyu',
#    'id': '053cszYX7LNud5wU0n7Vyu',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Toda Gloria',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/783983b83702d4c80f6c9e23724dbf8a86cc8eb6?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:053cszYX7LNud5wU0n7Vyu'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TBelHm5l0weOFZ9yXRkvn'},
#       'href': 'https://api.spotify.com/v1/artists/1TBelHm5l0weOFZ9yXRkvn',
#       'id': '1TBelHm5l0weOFZ9yXRkvn',
#       'name': 'Karl Olgeirsson',
#       'type': 'artist',
#       'uri': 'spotify:artist:1TBelHm5l0weOFZ9yXRkvn'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1iLu6vaM8PTLUBiwS05dok'},
#     'href': 'https://api.spotify.com/v1/albums/1iLu6vaM8PTLUBiwS05dok',
#     'id': '1iLu6vaM8PTLUBiwS05dok',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27389cf3cbbe32b1b7a780f0286',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0289cf3cbbe32b1b7a780f0286',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485189cf3cbbe32b1b7a780f0286',
#       'width': 64}],
#     'name': 'Mitt bláa hjarta',
#     'release_date': '2018-09-21',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:1iLu6vaM8PTLUBiwS05dok'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TBelHm5l0weOFZ9yXRkvn'},
#      'href': 'https://api.spotify.com/v1/artists/1TBelHm5l0weOFZ9yXRkvn',
#      'id': '1TBelHm5l0weOFZ9yXRkvn',
#      'name': 'Karl Olgeirsson',
#      'type': 'artist',
#      'uri': 'spotify:artist:1TBelHm5l0weOFZ9yXRkvn'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1AFn9LXe9swmdGrvtV2WGY'},
#      'href': 'https://api.spotify.com/v1/artists/1AFn9LXe9swmdGrvtV2WGY',
#      'id': '1AFn9LXe9swmdGrvtV2WGY',
#      'name': 'Helgi Jonsson',
#      'type': 'artist',
#      'uri': 'spotify:artist:1AFn9LXe9swmdGrvtV2WGY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6GBsjZ8qGJpZuuVlsurdku'},
#      'href': 'https://api.spotify.com/v1/artists/6GBsjZ8qGJpZuuVlsurdku',
#      'id': '6GBsjZ8qGJpZuuVlsurdku',
#      'name': 'Asgeir Asgeirsson',
#      'type': 'artist',
#      'uri': 'spotify:artist:6GBsjZ8qGJpZuuVlsurdku'}],
#    'disc_number': 1,
#    'duration_ms': 437066,
#    'explicit': False,
#    'external_ids': {'isrc': 'ISV441838513'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/053knf07q5A1pPPMrxczMU'},
#    'href': 'https://api.spotify.com/v1/tracks/053knf07q5A1pPPMrxczMU',
#    'id': '053knf07q5A1pPPMrxczMU',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Skýjaglópur',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8248719028bf6770050fa7c2ddcc2636e78d347d?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:053knf07q5A1pPPMrxczMU'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eDvtTsWtZl6qRfdjq8uyr'},
#       'href': 'https://api.spotify.com/v1/artists/1eDvtTsWtZl6qRfdjq8uyr',
#       'id': '1eDvtTsWtZl6qRfdjq8uyr',
#       'name': 'Felix Cumbe',
#       'type': 'artist',
#       'uri': 'spotify:artist:1eDvtTsWtZl6qRfdjq8uyr'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0DNKZqLMhyE38tra6FXoU0'},
#     'href': 'https://api.spotify.com/v1/albums/0DNKZqLMhyE38tra6FXoU0',
#     'id': '0DNKZqLMhyE38tra6FXoU0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ccf3d75e8dc3fe3e7066f89d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ccf3d75e8dc3fe3e7066f89d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ccf3d75e8dc3fe3e7066f89d',
#       'width': 64}],
#     'name': 'Merengue Clasicos (1980 - 1990)',
#     'release_date': '2018-02-27',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:0DNKZqLMhyE38tra6FXoU0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eDvtTsWtZl6qRfdjq8uyr'},
#      'href': 'https://api.spotify.com/v1/artists/1eDvtTsWtZl6qRfdjq8uyr',
#      'id': '1eDvtTsWtZl6qRfdjq8uyr',
#      'name': 'Felix Cumbe',
#      'type': 'artist',
#      'uri': 'spotify:artist:1eDvtTsWtZl6qRfdjq8uyr'}],
#    'disc_number': 7,
#    'duration_ms': 242704,
#    'explicit': False,
#    'external_ids': {'isrc': 'uscgj1815745'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/053riR1689Pc1NfsxTSej3'},
#    'href': 'https://api.spotify.com/v1/tracks/053riR1689Pc1NfsxTSej3',
#    'id': '053riR1689Pc1NfsxTSej3',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Madame Ale Cayiu',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/25d9be95dc53c7eb89efb40ca1c08ee2e8d2f2f7?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:053riR1689Pc1NfsxTSej3'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CqxabZ2gSzwh36ttI2tHg'},
#       'href': 'https://api.spotify.com/v1/artists/4CqxabZ2gSzwh36ttI2tHg',
#       'id': '4CqxabZ2gSzwh36ttI2tHg',
#       'name': 'Zséda',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CqxabZ2gSzwh36ttI2tHg'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/32F5jEKR97YEv1BX2YlaD1'},
#     'href': 'https://api.spotify.com/v1/albums/32F5jEKR97YEv1BX2YlaD1',
#     'id': '32F5jEKR97YEv1BX2YlaD1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732098f44f2848d9b34949eeac',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022098f44f2848d9b34949eeac',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512098f44f2848d9b34949eeac',
#       'width': 64}],
#     'name': 'Fosszíliák',
#     'release_date': '2018-09-06',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:32F5jEKR97YEv1BX2YlaD1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CqxabZ2gSzwh36ttI2tHg'},
#      'href': 'https://api.spotify.com/v1/artists/4CqxabZ2gSzwh36ttI2tHg',
#      'id': '4CqxabZ2gSzwh36ttI2tHg',
#      'name': 'Zséda',
#      'type': 'artist',
#      'uri': 'spotify:artist:4CqxabZ2gSzwh36ttI2tHg'}],
#    'disc_number': 1,
#    'duration_ms': 218134,
#    'explicit': False,
#    'external_ids': {'isrc': 'HUMAG1800159'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/054FTHxDj0ioJCCanYzzhj'},
#    'href': 'https://api.spotify.com/v1/tracks/054FTHxDj0ioJCCanYzzhj',
#    'id': '054FTHxDj0ioJCCanYzzhj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Fosszíliák',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f3f7ee6e9bf0ddee5f78bfddcc27f441738b1aad?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:054FTHxDj0ioJCCanYzzhj'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TgQoPS3u2LeBPZFtIyQ0y'},
#       'href': 'https://api.spotify.com/v1/artists/2TgQoPS3u2LeBPZFtIyQ0y',
#       'id': '2TgQoPS3u2LeBPZFtIyQ0y',
#       'name': 'Fattybass',
#       'type': 'artist',
#       'uri': 'spotify:artist:2TgQoPS3u2LeBPZFtIyQ0y'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3fRUfm18Fs6MFKKy9Hkydq'},
#     'href': 'https://api.spotify.com/v1/albums/3fRUfm18Fs6MFKKy9Hkydq',
#     'id': '3fRUfm18Fs6MFKKy9Hkydq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27377963cdc6331c5dfccc32f84',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0277963cdc6331c5dfccc32f84',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485177963cdc6331c5dfccc32f84',
#       'width': 64}],
#     'name': 'Sirens',
#     'release_date': '2018-05-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3fRUfm18Fs6MFKKy9Hkydq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TgQoPS3u2LeBPZFtIyQ0y'},
#      'href': 'https://api.spotify.com/v1/artists/2TgQoPS3u2LeBPZFtIyQ0y',
#      'id': '2TgQoPS3u2LeBPZFtIyQ0y',
#      'name': 'Fattybass',
#      'type': 'artist',
#      'uri': 'spotify:artist:2TgQoPS3u2LeBPZFtIyQ0y'}],
#    'disc_number': 1,
#    'duration_ms': 211043,
#    'explicit': False,
#    'external_ids': {'isrc': 'AEA0Q1875547'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/054VshHz40gfJ24bWNAzM9'},
#    'href': 'https://api.spotify.com/v1/tracks/054VshHz40gfJ24bWNAzM9',
#    'id': '054VshHz40gfJ24bWNAzM9',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Sirens',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a65b3064e16cdeda4ef423c82a8893e809c1c73c?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:054VshHz40gfJ24bWNAzM9'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29I1g9QjniedTIZUwSBMG5'},
#       'href': 'https://api.spotify.com/v1/artists/29I1g9QjniedTIZUwSBMG5',
#       'id': '29I1g9QjniedTIZUwSBMG5',
#       'name': 'Pony Marshall',
#       'type': 'artist',
#       'uri': 'spotify:artist:29I1g9QjniedTIZUwSBMG5'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4ns2KPrMekZsvo1XIjeWmy'},
#     'href': 'https://api.spotify.com/v1/albums/4ns2KPrMekZsvo1XIjeWmy',
#     'id': '4ns2KPrMekZsvo1XIjeWmy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736d425e3a5cbfd6a998a22d60',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026d425e3a5cbfd6a998a22d60',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516d425e3a5cbfd6a998a22d60',
#       'width': 64}],
#     'name': 'Solitude',
#     'release_date': '2018-12-07',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4ns2KPrMekZsvo1XIjeWmy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29I1g9QjniedTIZUwSBMG5'},
#      'href': 'https://api.spotify.com/v1/artists/29I1g9QjniedTIZUwSBMG5',
#      'id': '29I1g9QjniedTIZUwSBMG5',
#      'name': 'Pony Marshall',
#      'type': 'artist',
#      'uri': 'spotify:artist:29I1g9QjniedTIZUwSBMG5'}],
#    'disc_number': 1,
#    'duration_ms': 247826,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBLPF0215788'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/054p6DTdDUylIODeeZ17HW'},
#    'href': 'https://api.spotify.com/v1/tracks/054p6DTdDUylIODeeZ17HW',
#    'id': '054p6DTdDUylIODeeZ17HW',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Solitude',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/539b6006b81e66bc525b347d1405745e6e54c4b5?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:054p6DTdDUylIODeeZ17HW'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4lFmHaaR3XATl9yVLqWuhz'},
#       'href': 'https://api.spotify.com/v1/artists/4lFmHaaR3XATl9yVLqWuhz',
#       'id': '4lFmHaaR3XATl9yVLqWuhz',
#       'name': 'Keosz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4lFmHaaR3XATl9yVLqWuhz'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3iPLSZWuQPUM9dv2pBJLqM'},
#     'href': 'https://api.spotify.com/v1/albums/3iPLSZWuQPUM9dv2pBJLqM',
#     'id': '3iPLSZWuQPUM9dv2pBJLqM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27312fa8e8c6fa772bfa98dc258',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0212fa8e8c6fa772bfa98dc258',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485112fa8e8c6fa772bfa98dc258',
#       'width': 64}],
#     'name': 'No Future, Vol. 2',
#     'release_date': '2018-09-29',
#     'release_date_precision': 'day',
#     'total_tracks': 25,
#     'type': 'album',
#     'uri': 'spotify:album:3iPLSZWuQPUM9dv2pBJLqM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4lFmHaaR3XATl9yVLqWuhz'},
#      'href': 'https://api.spotify.com/v1/artists/4lFmHaaR3XATl9yVLqWuhz',
#      'id': '4lFmHaaR3XATl9yVLqWuhz',
#      'name': 'Keosz',
#      'type': 'artist',
#      'uri': 'spotify:artist:4lFmHaaR3XATl9yVLqWuhz'}],
#    'disc_number': 1,
#    'duration_ms': 218713,
#    'explicit': False,
#    'external_ids': {'isrc': 'UST8K1834867'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/055BIKFibQwvy1JouM9mGl'},
#    'href': 'https://api.spotify.com/v1/tracks/055BIKFibQwvy1JouM9mGl',
#    'id': '055BIKFibQwvy1JouM9mGl',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Vice City',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b9cdc7fe035d87a6b6c7bbb32aa132c0c73c5f06?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:055BIKFibQwvy1JouM9mGl'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74qGVun4j6ACNMFYdFohQf'},
#       'href': 'https://api.spotify.com/v1/artists/74qGVun4j6ACNMFYdFohQf',
#       'id': '74qGVun4j6ACNMFYdFohQf',
#       'name': '饭思思',
#       'type': 'artist',
#       'uri': 'spotify:artist:74qGVun4j6ACNMFYdFohQf'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7lXFmG4yXmjt92EpK3MWv1'},
#     'href': 'https://api.spotify.com/v1/albums/7lXFmG4yXmjt92EpK3MWv1',
#     'id': '7lXFmG4yXmjt92EpK3MWv1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27326016a9da12bd0c7b310ad13',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0226016a9da12bd0c7b310ad13',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485126016a9da12bd0c7b310ad13',
#       'width': 64}],
#     'name': '最初的心动',
#     'release_date': '2018-12-09',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:7lXFmG4yXmjt92EpK3MWv1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74qGVun4j6ACNMFYdFohQf'},
#      'href': 'https://api.spotify.com/v1/artists/74qGVun4j6ACNMFYdFohQf',
#      'id': '74qGVun4j6ACNMFYdFohQf',
#      'name': '饭思思',
#      'type': 'artist',
#      'uri': 'spotify:artist:74qGVun4j6ACNMFYdFohQf'}],
#    'disc_number': 1,
#    'duration_ms': 195428,
#    'explicit': False,
#    'external_ids': {'isrc': 'HKG731800016'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/055WmcHUZkqw3jjxOrraCG'},
#    'href': 'https://api.spotify.com/v1/tracks/055WmcHUZkqw3jjxOrraCG',
#    'id': '055WmcHUZkqw3jjxOrraCG',
#    'is_local': False,
#    'is_playable': True,
#    'name': '最初的心动',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/610343e45d52bed7ddb56183784fb3787448e8ed?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:055WmcHUZkqw3jjxOrraCG'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/756RXinde3TxCitWAmp8Vq'},
# ...
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3M8sLWbS13j8JgYEUowidq'},
#      'href': 'https://api.spotify.com/v1/artists/3M8sLWbS13j8JgYEUowidq',
#      'id': '3M8sLWbS13j8JgYEUowidq',
#      'name': 'Fresh N Dope',
#      'type': 'artist',
#      'uri': 'spotify:artist:3M8sLWbS13j8JgYEUowidq'}],
#    'disc_number': 1,
#    'duration_ms': 186424,
#    'explicit': True,
#    'external_ids': {'isrc': 'PLUM71800817'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05ApDlCmomIp481p5bejIW'},
#    'href': 'https://api.spotify.com/v1/tracks/05ApDlCmomIp481p5bejIW',
#    'id': '05ApDlCmomIp481p5bejIW',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Akademik',
#    'popularity': 3,
#    'preview_url': None,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:05ApDlCmomIp481p5bejIW'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3YZxGuk1m0pUoyZRCMcLDh'},
#       'href': 'https://api.spotify.com/v1/artists/3YZxGuk1m0pUoyZRCMcLDh',
#       'id': '3YZxGuk1m0pUoyZRCMcLDh',
#       'name': 'Mohamad Outhnawt',
#       'type': 'artist',
#       'uri': 'spotify:artist:3YZxGuk1m0pUoyZRCMcLDh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4wTvWgCxE9ECJetnYSQ3Yv'},
#     'href': 'https://api.spotify.com/v1/albums/4wTvWgCxE9ECJetnYSQ3Yv',
#     'id': '4wTvWgCxE9ECJetnYSQ3Yv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733732bd97f625d68c410bb963',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023732bd97f625d68c410bb963',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513732bd97f625d68c410bb963',
#       'width': 64}],
#     'name': 'Nigh Bismillah',
#     'release_date': '2018-10-26',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:4wTvWgCxE9ECJetnYSQ3Yv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3YZxGuk1m0pUoyZRCMcLDh'},
#      'href': 'https://api.spotify.com/v1/artists/3YZxGuk1m0pUoyZRCMcLDh',
#      'id': '3YZxGuk1m0pUoyZRCMcLDh',
#      'name': 'Mohamad Outhnawt',
#      'type': 'artist',
#      'uri': 'spotify:artist:3YZxGuk1m0pUoyZRCMcLDh'}],
#    'disc_number': 1,
#    'duration_ms': 333392,
#    'explicit': False,
#    'external_ids': {'isrc': 'ESA011821902'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05BECWXOQA9nRhsolRu48x'},
#    'href': 'https://api.spotify.com/v1/tracks/05BECWXOQA9nRhsolRu48x',
#    'id': '05BECWXOQA9nRhsolRu48x',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Dalb Irbbi',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/446e256f8c905274e4c330d281ec7c41b6096aa0?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:05BECWXOQA9nRhsolRu48x'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05BimyoMbuMGEBJjSRDK0a'},
#       'href': 'https://api.spotify.com/v1/artists/05BimyoMbuMGEBJjSRDK0a',
#       'id': '05BimyoMbuMGEBJjSRDK0a',
#       'name': 'Bolivar Peralta',
#       'type': 'artist',
#       'uri': 'spotify:artist:05BimyoMbuMGEBJjSRDK0a'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/38f27ItMVeolDDQcFJKMyu'},
#     'href': 'https://api.spotify.com/v1/albums/38f27ItMVeolDDQcFJKMyu',
#     'id': '38f27ItMVeolDDQcFJKMyu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273207aad17abb49acc1e9b8f9b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02207aad17abb49acc1e9b8f9b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851207aad17abb49acc1e9b8f9b',
#       'width': 64}],
#     'name': '15 Exitos',
#     'release_date': '2018-05-04',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:38f27ItMVeolDDQcFJKMyu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05BimyoMbuMGEBJjSRDK0a'},
#      'href': 'https://api.spotify.com/v1/artists/05BimyoMbuMGEBJjSRDK0a',
#      'id': '05BimyoMbuMGEBJjSRDK0a',
#      'name': 'Bolivar Peralta',
#      'type': 'artist',
#      'uri': 'spotify:artist:05BimyoMbuMGEBJjSRDK0a'}],
#    'disc_number': 1,
#    'duration_ms': 173733,
#    'explicit': False,
#    'external_ids': {'isrc': 'DOA251800028'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05C2svDk8favywkM6fBlv0'},
#    'href': 'https://api.spotify.com/v1/tracks/05C2svDk8favywkM6fBlv0',
#    'id': '05C2svDk8favywkM6fBlv0',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Espero por Mi Morena',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c853cd196f880a6430c63106519f59182dc128ea?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:05C2svDk8favywkM6fBlv0'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Anz2KY3x2hKdhUxaDK1Zm'},
#       'href': 'https://api.spotify.com/v1/artists/2Anz2KY3x2hKdhUxaDK1Zm',
#       'id': '2Anz2KY3x2hKdhUxaDK1Zm',
#       'name': 'Мила Роберт',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Anz2KY3x2hKdhUxaDK1Zm'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5jMiV4YTcRDhy2Y4Qexzkm'},
#     'href': 'https://api.spotify.com/v1/albums/5jMiV4YTcRDhy2Y4Qexzkm',
#     'id': '5jMiV4YTcRDhy2Y4Qexzkm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736a947cbc6dd4d4c350dc415e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026a947cbc6dd4d4c350dc415e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516a947cbc6dd4d4c350dc415e',
#       'width': 64}],
#     'name': 'Наше си е, Саше',
#     'release_date': '2018-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5jMiV4YTcRDhy2Y4Qexzkm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Anz2KY3x2hKdhUxaDK1Zm'},
#      'href': 'https://api.spotify.com/v1/artists/2Anz2KY3x2hKdhUxaDK1Zm',
#      'id': '2Anz2KY3x2hKdhUxaDK1Zm',
#      'name': 'Мила Роберт',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Anz2KY3x2hKdhUxaDK1Zm'}],
#    'disc_number': 1,
#    'duration_ms': 165748,
#    'explicit': False,
#    'external_ids': {'isrc': 'BGA261578009'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05CZU4k4WXD0ZTYpF87t4G'},
#    'href': 'https://api.spotify.com/v1/tracks/05CZU4k4WXD0ZTYpF87t4G',
#    'id': '05CZU4k4WXD0ZTYpF87t4G',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Наше си е, Саше',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5730496662ce457589b011fa94425ded9eeca125?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05CZU4k4WXD0ZTYpF87t4G'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bOYFg7eEyHMA6wBK99Rv2'},
#       'href': 'https://api.spotify.com/v1/artists/2bOYFg7eEyHMA6wBK99Rv2',
#       'id': '2bOYFg7eEyHMA6wBK99Rv2',
#       'name': 'LAZZI',
#       'type': 'artist',
#       'uri': 'spotify:artist:2bOYFg7eEyHMA6wBK99Rv2'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7hHj2eVrqt30CBXhRdkdAK'},
#     'href': 'https://api.spotify.com/v1/albums/7hHj2eVrqt30CBXhRdkdAK',
#     'id': '7hHj2eVrqt30CBXhRdkdAK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273efeb482a3579e25f1020646f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02efeb482a3579e25f1020646f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851efeb482a3579e25f1020646f',
#       'width': 64}],
#     'name': 'Bumbaa',
#     'release_date': '2018-06-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7hHj2eVrqt30CBXhRdkdAK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bOYFg7eEyHMA6wBK99Rv2'},
#      'href': 'https://api.spotify.com/v1/artists/2bOYFg7eEyHMA6wBK99Rv2',
#      'id': '2bOYFg7eEyHMA6wBK99Rv2',
#      'name': 'LAZZI',
#      'type': 'artist',
#      'uri': 'spotify:artist:2bOYFg7eEyHMA6wBK99Rv2'}],
#    'disc_number': 1,
#    'duration_ms': 150836,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCADT1844652'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05CboX8OTxRM19caluPOnb'},
#    'href': 'https://api.spotify.com/v1/tracks/05CboX8OTxRM19caluPOnb',
#    'id': '05CboX8OTxRM19caluPOnb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bumbaa',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/89cc7ffd4f9338f91bc8f16bb3daed5dc00e11c3?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05CboX8OTxRM19caluPOnb'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rrGMzziGpsTFTSeCEs1ou'},
#       'href': 'https://api.spotify.com/v1/artists/5rrGMzziGpsTFTSeCEs1ou',
#       'id': '5rrGMzziGpsTFTSeCEs1ou',
#       'name': 'Affect',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rrGMzziGpsTFTSeCEs1ou'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4OBE68cwB4QFv2ui0qFHag'},
#     'href': 'https://api.spotify.com/v1/albums/4OBE68cwB4QFv2ui0qFHag',
#     'id': '4OBE68cwB4QFv2ui0qFHag',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27322af52c0052f18a7ac79010c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0222af52c0052f18a7ac79010c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485122af52c0052f18a7ac79010c',
#       'width': 64}],
#     'name': 'Наследство',
#     'release_date': '2018-04-16',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:4OBE68cwB4QFv2ui0qFHag'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rrGMzziGpsTFTSeCEs1ou'},
#      'href': 'https://api.spotify.com/v1/artists/5rrGMzziGpsTFTSeCEs1ou',
#      'id': '5rrGMzziGpsTFTSeCEs1ou',
#      'name': 'Affect',
#      'type': 'artist',
#      'uri': 'spotify:artist:5rrGMzziGpsTFTSeCEs1ou'}],
#    'disc_number': 1,
#    'duration_ms': 269080,
#    'explicit': False,
#    'external_ids': {'isrc': 'SEYOK1828716'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05EJshxMP7cls0HXxE5WWL'},
#    'href': 'https://api.spotify.com/v1/tracks/05EJshxMP7cls0HXxE5WWL',
#    'id': '05EJshxMP7cls0HXxE5WWL',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Мойте кафеви очи',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ebbb39749866eaaad75189334adf6e37850340d3?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:05EJshxMP7cls0HXxE5WWL'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24Pl5vknldjXTM3KtGEv9R'},
#       'href': 'https://api.spotify.com/v1/artists/24Pl5vknldjXTM3KtGEv9R',
#       'id': '24Pl5vknldjXTM3KtGEv9R',
#       'name': 'Hase',
#       'type': 'artist',
#       'uri': 'spotify:artist:24Pl5vknldjXTM3KtGEv9R'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0UAWKdS1Vv6EKatELCjk3C'},
#     'href': 'https://api.spotify.com/v1/albums/0UAWKdS1Vv6EKatELCjk3C',
#     'id': '0UAWKdS1Vv6EKatELCjk3C',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ae815d0de65ddbf695e98bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ae815d0de65ddbf695e98bf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ae815d0de65ddbf695e98bf',
#       'width': 64}],
#     'name': 'Najlepszego',
#     'release_date': '2018-08-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0UAWKdS1Vv6EKatELCjk3C'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24Pl5vknldjXTM3KtGEv9R'},
#      'href': 'https://api.spotify.com/v1/artists/24Pl5vknldjXTM3KtGEv9R',
#      'id': '24Pl5vknldjXTM3KtGEv9R',
#      'name': 'Hase',
#      'type': 'artist',
#      'uri': 'spotify:artist:24Pl5vknldjXTM3KtGEv9R'}],
#    'disc_number': 1,
#    'duration_ms': 220551,
#    'explicit': False,
#    'external_ids': {'isrc': 'PLS411800016'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05En7rxUrMMIWSDoKetQJE'},
#    'href': 'https://api.spotify.com/v1/tracks/05En7rxUrMMIWSDoKetQJE',
#    'id': '05En7rxUrMMIWSDoKetQJE',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Najlepszego',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/63699b97c4d690eb288c8abf2ed3b799e740b40a?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05En7rxUrMMIWSDoKetQJE'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/32vpj3OfAguCApf3kgX6Hi'},
#       'href': 'https://api.spotify.com/v1/artists/32vpj3OfAguCApf3kgX6Hi',
#       'id': '32vpj3OfAguCApf3kgX6Hi',
#       'name': 'VKL',
#       'type': 'artist',
#       'uri': 'spotify:artist:32vpj3OfAguCApf3kgX6Hi'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/63TB3p6JwwW8P9wmeu12DS'},
#     'href': 'https://api.spotify.com/v1/albums/63TB3p6JwwW8P9wmeu12DS',
#     'id': '63TB3p6JwwW8P9wmeu12DS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273743ff01709030db98bbd61bd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02743ff01709030db98bbd61bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851743ff01709030db98bbd61bd',
#       'width': 64}],
#     'name': 'Over Control',
#     'release_date': '2018-02-18',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:63TB3p6JwwW8P9wmeu12DS'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/32vpj3OfAguCApf3kgX6Hi'},
#      'href': 'https://api.spotify.com/v1/artists/32vpj3OfAguCApf3kgX6Hi',
#      'id': '32vpj3OfAguCApf3kgX6Hi',
#      'name': 'VKL',
#      'type': 'artist',
#      'uri': 'spotify:artist:32vpj3OfAguCApf3kgX6Hi'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2xW33QJdQkUruZADfAe7SU'},
#      'href': 'https://api.spotify.com/v1/artists/2xW33QJdQkUruZADfAe7SU',
#      'id': '2xW33QJdQkUruZADfAe7SU',
#      'name': 'Mona',
#      'type': 'artist',
#      'uri': 'spotify:artist:2xW33QJdQkUruZADfAe7SU'}],
#    'disc_number': 1,
#    'duration_ms': 181258,
#    'explicit': True,
#    'external_ids': {'isrc': 'THMOB1804023'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05FUsCBqsu9Y0hQSryVjX2'},
#    'href': 'https://api.spotify.com/v1/tracks/05FUsCBqsu9Y0hQSryVjX2',
#    'id': '05FUsCBqsu9Y0hQSryVjX2',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'OldBoy',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f561a68105d21f29b3cb9c43e9de146453991571?cid=51c2d40e57e74fbb852374c80b4f0054',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:05FUsCBqsu9Y0hQSryVjX2'}],
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/search?query=year%3A2018+AND+tag%3Ahipster&type=track&market=US&offset=2000&limit=50',
#  'offset': 1950,
#  'previous': 'https://api.spotify.com/v1/search?query=year%3A2018+AND+tag%3Ahipster&type=track&market=US&offset=1900&limit=50',
#  'total': 100000}

# %%
#track_results['tracks']

# %%
# imports.
import pandas as pd

# create the tracks data frame.
df_tracks = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'track_id':track_id,'popularity':popularity})
# show the data frame shape.
print(df_tracks.shape)
# show the data frame with headers.
df_tracks.head()
# Out:
# (2000, 4)
#                    artist_name  ... popularity
# 0                 Luis Estrada  ...          4
# 1  Sabrina Is Not In This Chat  ...          4
# 2                 Luis Estrada  ...          4
# 3                  Leah Voysey  ...          4
# 4                Andrei Krylov  ...          4
#
# [5 rows x 4 columns]

# %%
# group entries by artist_name and track_name, check for duplicates.
grouped = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
print(grouped[grouped > 1].count())
df_tracks.drop_duplicates(subset=['artist_name','track_name'], inplace=True)
# Out:
# 46

# %%
# verify duplicates were dropped.
grouped_after_dropping = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
grouped_after_dropping[grouped_after_dropping > 1].count()
# Out:
# 0

# %%
# show basic info for tracks data.
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1954 entries, 0 to 1999
# Data columns (total 4 columns):
# artist_name    1954 non-null object
# track_name     1954 non-null object
# track_id       1954 non-null object
# popularity     1954 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 76.3+ KB

# %% [markdown]
# ### Track Audio Features Data.

# %%
# timeit library to measure the time needed to run this code.
start = timeit.default_timer()

# empty list, batchsize, counter for 'none' results.
rows = []
batchsize = 100
None_counter = 0

for i in range(0,len(df_tracks['track_id']),batchsize):
    batch = df_tracks['track_id'][i:i+batchsize]
    feature_results = sp.audio_features(batch)
    for i, t in enumerate(feature_results):
        if t == None:
            None_counter = None_counter + 1
        else:
            rows.append(t)
            
print('Number of tracks where no audio features were available:',None_counter)
stop = timeit.default_timer()
print ('Time to run this code (in seconds):',stop - start)
# Out:
# Number of tracks where no audio features were available: 0
# Time to run this code (in seconds): 3.0535056440003245

# %%
# create the audio features data frame.
df_audio_features = pd.DataFrame.from_dict(rows,orient='columns')
# show the shape of the data frame.
print(df_audio_features.shape)
# show the data frame with headers.
df_audio_features.head()
# Out:
# (1954, 18)
#    danceability  energy  ...  duration_ms  time_signature
# 0         0.688   0.826  ...       213600               4
# 1         0.522   0.744  ...       236151               4
# 2         0.785   0.923  ...       236743               4
# 3         0.576   0.650  ...       139605               4
# 4         0.528   0.150  ...       102940               3
#
# [5 rows x 18 columns]

# %%
# show basic info for audio features data.
df_audio_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1954 entries, 0 to 1953
# Data columns (total 18 columns):
# danceability        1954 non-null float64
# energy              1954 non-null float64
# key                 1954 non-null int64
# loudness            1954 non-null float64
# mode                1954 non-null int64
# speechiness         1954 non-null float64
# acousticness        1954 non-null float64
# instrumentalness    1954 non-null float64
# liveness            1954 non-null float64
# valence             1954 non-null float64
# tempo               1954 non-null float64
# type                1954 non-null object
# id                  1954 non-null object
# uri                 1954 non-null object
# track_href          1954 non-null object
# analysis_url        1954 non-null object
# duration_ms         1954 non-null int64
# time_signature      1954 non-null int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 274.9+ KB

# %%
# rename id column to merge with tracks data frame.
df_audio_features.rename(columns={'id': 'track_id'}, inplace=True)

# %%
# drop useless columns.
columns_to_drop = ['analysis_url','track_href','type','uri']
df_audio_features.drop(columns_to_drop, axis=1,inplace=True)
# show the data frame shape.
print(df_audio_features.shape)
# Out:
# (1954, 14)

# %%
# merge both dataframes with inner method to keep track IDs present in both data frames.
df = pd.merge(df_tracks,df_audio_features,on='track_id',how='inner')
print(df.shape)
df.head()
# Out:
# (1954, 17)
#                    artist_name  ... time_signature
# 0                 Luis Estrada  ...              4
# 1  Sabrina Is Not In This Chat  ...              4
# 2                 Luis Estrada  ...              4
# 3                  Leah Voysey  ...              4
# 4                Andrei Krylov  ...              3
#
# [5 rows x 17 columns]

# %% [markdown]
# ### Final.

# %%
# check for NA values.
df.isna().sum()
# Out:
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
#print(df.shape)
df.head()
# Out:
#                    artist_name  ... time_signature
# 0                 Luis Estrada  ...              4
# 1  Sabrina Is Not In This Chat  ...              4
# 2                 Luis Estrada  ...              4
# 3                  Leah Voysey  ...              4
# 4                Andrei Krylov  ...              3
#
# [5 rows x 17 columns]

# %% [markdown]
# ### Create a CSV file.

# %%
from google.colab import files
df.to_csv('SpotifyTracks_2018hipster.csv')
files.download('SpotifyTracks_2018hipster.csv')
