# %%
# imports.
import pandas as pd
import numpy as np
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# read in the tracks data.
df1 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/spotify-app/master/ds/Data/SpotifyTracks_doubleforloop_genre_year.csv', index_col=0)
# show the data frame shape.
print(df1.shape)
# show the data frame with headers.
df1.head()
# Out:
# (164449, 20)
#          artist_name          track_name  ... time_signature  valence
# 0           Gorillaz  On Melancholy Hill  ...              4    0.578
# 1  Avenged Sevenfold           Nightmare  ...              4    0.233
# 2     The Black Keys     Howlin' for You  ...              4    0.448
# 3    My Darkest Days   Porn Star Dancing  ...              4    0.271
# 4            Volbeat    A Warrior's Call  ...              3    0.429
#
# [5 rows x 20 columns]

# %%
# read in the moods data.
df2 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/spotify-app/master/ds/Data/Spotify_MoodsDataSurvey.csv')
df2.fillna(0, inplace=True)
# show the data frame shape.
print(df2.shape)
# show the data frame with headers.
df2.head(16)
# Out:
# (16, 11)
#                                       Name  Calming  ...  Wake up  Not Standardized
# 0                    Ariana Grande - Needy      1.0  ...      0.0                 2
# 1   Cigarettes After Sex - Don't Let Me Go      0.0  ...      2.0                 2
# 2              Drake ft. Jay Z - Talk Up\n      0.0  ...      0.0                 2
# 3                 Fifth Harmony - Worth It      0.0  ...      0.0                 1
# 4         Justin Bieber - All That Matters      2.0  ...      0.0                 1
# 5               Lil Uzi Vert - Hi Roller\n      1.0  ...      0.0                 2
# 6               Mac Miller - Best Day Ever      0.0  ...      1.0                 2
# 7                    Max - Lights Down Low      2.0  ...      0.0                 1
# 8                 No Vacation - Dream Girl      0.0  ...      0.0                 2
# 9                        Noah Kahan - Sink      3.0  ...      1.0                 2
# ...

# %%
# show the column names.
df2.columns
# Out:
# Index(['Name', 'Calming', 'Excited ', 'Happy', 'Head Bobbers', 'I'm a boss',
#        'Mad Energized', 'Motivated', 'Unwind & Relax', 'Wake up',
#        'Not Standardized'],
#       dtype='object')

# %%
# find the artist name/track name from df2 in df1.
df1[df1.artist_name.str.contains('Zac Brown Band',case=False) & df1.track_name.str.contains('Castaway',case=False)]
# Out:
#           artist_name track_name  ... time_signature  valence
# 73129  Zac Brown Band   Castaway  ...              4    0.915
#
# [1 rows x 20 columns]

# %%
# rise.
4t2rjxCXIJnBmRBkXJOYa5 = excited 
# mac.
504jTZvXdP8YYVtd19rfuX = happy 
# justin.
70XP39KE8vTgxtRXcwfxJA - motivated 
# zac.
5PNcJn4oFNvlRfrZBHfqWh - happy
# fifth.
41Fflg7qHiVOD6dEPvsCzO - im a boss
# no.
6lbLn5iL2NBJnbib7bTXMn - happy
# rihanna.
5oO3drDxtziYU2H1X23ZIp - unwind & relax
# max.
5A6BJLZArq1MPjsnmcuk5f - unwind & relex
# weeknd.
15k2nBQJ0teDmPZHrOXL2N - unwind & relax
# lil. 
69M9QCMsCQ5MLsw7BBW0rL - mad energized 
# russ.
4nqdlZEyfCTE6vqm58XTrI - calming
# noah.
3EIaMTBMRM42nbEROLg7cZ - calming 
# talk.
4ksuI04WMvUnJbHQjgs3L5 - head bobbers 
# ariana.
1TEL6MlSSVLSdhOSddidlJ - unwind & relax
# cigarettes.
0dBQm6NsxCQ1cOwR4zWw89 - wake up 
# post.
21jGcNKet2qwijlDFuPiPb - motivated

# %%
# collect all the track ids in the df1 data into a new data frame.
tracks = ['1TEL6MlSSVLSdhOSddidlJ','0dBQm6NsxCQ1cOwR4zWw89','4ksuI04WMvUnJbHQjgs3L5',
                              '41Fflg7qHiVOD6dEPvsCzO','70XP39KE8vTgxtRXcwfxJA','69M9QCMsCQ5MLsw7BBW0rL',
                              '504jTZvXdP8YYVtd19rfuX','5A6BJLZArq1MPjsnmcuk5f','6lbLn5iL2NBJnbib7bTXMn',
                              '3EIaMTBMRM42nbEROLg7cZ','21jGcNKet2qwijlDFuPiPb','5oO3drDxtziYU2H1X23ZIp',
                              '4t2rjxCXIJnBmRBkXJOYa5','4nqdlZEyfCTE6vqm58XTrI','15k2nBQJ0teDmPZHrOXL2N',
                              '5PNcJn4oFNvlRfrZBHfqWh']
df1.track_id.isin(tracks)
df3 = df1[df1.track_id.isin(tracks)]

# %%
# show the data frame shape.
print(df3.shape)
# show the data frame with headers.
df3.head(16)
# Out:
# (16, 20)
#                  artist_name  ... valence
# 48618           Rise Against  ...   0.428
# 55603             Mac Miller  ...   0.262
# 68155          Justin Bieber  ...   0.144
# 73129         Zac Brown Band  ...   0.915
# 74887          Fifth Harmony  ...   0.594
# 78952            No Vacation  ...   0.262
# 89914                Rihanna  ...   0.378
# 89927                    MAX  ...   0.594
# 98537             The Weeknd  ...   0.361
# 98631           Lil Uzi Vert  ...   0.147
# 98851                   Russ  ...   0.382
# 118170            Noah Kahan  ...   0.293
# 131059                 Drake  ...   0.335
# 138296         Ariana Grande  ...   0.195
# 143020  Cigarettes After Sex  ...   0.162
# 149356           Post Malone  ...   0.553
#
# [16 rows x 20 columns]

# %%
# add a new column with the mood from the survey for the tracks.
df3['mood'] = ['Excited','Happy','Motivated','Happy','Im a boss','Happy','Unwind & Relax','Unwind & Relax','Unwind & Relax','Mad Energized', 'Calming','Calming','Head Bobbers','Unwind & Relax','Wake Up','Motivated']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# show the data frame shape.
print(df3.shape)
# show the data frame with headers.
df3.head(16)
# Out:
# (16, 21)
#                  artist_name  ...            mood
# 48618           Rise Against  ...         Excited
# 55603             Mac Miller  ...           Happy
# 68155          Justin Bieber  ...       Motivated
# 73129         Zac Brown Band  ...           Happy
# 74887          Fifth Harmony  ...       Im a boss
# 78952            No Vacation  ...           Happy
# 89914                Rihanna  ...  Unwind & Relax
# 89927                    MAX  ...  Unwind & Relax
# 98537             The Weeknd  ...  Unwind & Relax
# 98631           Lil Uzi Vert  ...   Mad Energized
# 98851                   Russ  ...         Calming
# 118170            Noah Kahan  ...         Calming
# 131059                 Drake  ...    Head Bobbers
# 138296         Ariana Grande  ...  Unwind & Relax
# 143020  Cigarettes After Sex  ...         Wake Up
# 149356           Post Malone  ...       Motivated
#
# [16 rows x 21 columns]

# %%
from google.colab import files
df3.to_csv('SpotifyMoodsData.csv')
files.download('SpotifyMoodsData.csv')
