# %% [markdown]
# ### Query for Year.

# %%
import pandas as pd

# read in all the spotify query data on year.
SpotifyTracks_2020 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2020.csv', index_col=0)
SpotifyTracks_2019 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2019.csv', index_col=0)
SpotifyTracks_2018 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2018.csv', index_col=0)
SpotifyTracks_2017 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2017.csv', index_col=0)
SpotifyTracks_2016 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2016.csv', index_col=0)
SpotifyTracks_2015 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2015.csv', index_col=0)
SpotifyTracks_2014 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2014.csv', index_col=0)
SpotifyTracks_2013 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2013.csv', index_col=0)
SpotifyTracks_2012 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2012.csv', index_col=0)
SpotifyTracks_2011 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2011.csv', index_col=0)
SpotifyTracks_2010 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2010.csv', index_col=0)
SpotifyTracks_2009 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2009.csv', index_col=0)
SpotifyTracks_2008 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2008.csv', index_col=0)
SpotifyTracks_2007 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2007.csv', index_col=0)
SpotifyTracks_2006 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2006.csv', index_col=0)
SpotifyTracks_2005 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2005.csv', index_col=0)
SpotifyTracks_2004 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2004.csv', index_col=0)
SpotifyTracks_2003 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2003.csv', index_col=0)
SpotifyTracks_2002 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2002.csv', index_col=0)
SpotifyTracks_2001 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2001.csv', index_col=0)
SpotifyTracks_2000 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_2000.csv', index_col=0)
SpotifyTracks_1999 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1999.csv', index_col=0)
SpotifyTracks_1998 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1998.csv', index_col=0)
SpotifyTracks_1997 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1997.csv', index_col=0)
SpotifyTracks_1996 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1996.csv', index_col=0)
SpotifyTracks_1995 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1995.csv', index_col=0)
SpotifyTracks_1994 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1994.csv', index_col=0)
SpotifyTracks_1993 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1993.csv', index_col=0)
SpotifyTracks_1992 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1992.csv', index_col=0)
SpotifyTracks_1991 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1991.csv', index_col=0)
SpotifyTracks_1990 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1990.csv', index_col=0)
SpotifyTracks_1989 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1989.csv', index_col=0)
SpotifyTracks_1988 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1988.csv', index_col=0)
SpotifyTracks_1987 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1987.csv', index_col=0)
SpotifyTracks_1986 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1986.csv', index_col=0)
SpotifyTracks_1985 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1985.csv', index_col=0)
SpotifyTracks_1984 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1984.csv', index_col=0)
SpotifyTracks_1983 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1983.csv', index_col=0)
SpotifyTracks_1982 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1982.csv', index_col=0)
SpotifyTracks_1981 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1981.csv', index_col=0)
SpotifyTracks_1980 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1980.csv', index_col=0)
SpotifyTracks_1979 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1979.csv', index_col=0)
SpotifyTracks_1978 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1978.csv', index_col=0)
SpotifyTracks_1977 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1977.csv', index_col=0)
SpotifyTracks_1976 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1976.csv', index_col=0)
SpotifyTracks_1975 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1975.csv', index_col=0)
SpotifyTracks_1974 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1974.csv', index_col=0)
SpotifyTracks_1973 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1973.csv', index_col=0)
SpotifyTracks_1972 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1972.csv', index_col=0)
SpotifyTracks_1971 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1971.csv', index_col=0)
SpotifyTracks_1970 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1970.csv', index_col=0)
SpotifyTracks_1969 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1969.csv', index_col=0)
SpotifyTracks_1968 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1968.csv', index_col=0)
SpotifyTracks_1967 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1967.csv', index_col=0)
SpotifyTracks_1966 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1966.csv', index_col=0)
SpotifyTracks_1965 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1965.csv', index_col=0)
SpotifyTracks_1964 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1964.csv', index_col=0)
SpotifyTracks_1963 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1963.csv', index_col=0)
SpotifyTracks_1962 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1962.csv', index_col=0)
SpotifyTracks_1961 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1961.csv', index_col=0)
SpotifyTracks_1960 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1960.csv', index_col=0)
SpotifyTracks_1959 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1959.csv', index_col=0)
SpotifyTracks_1958 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1958.csv', index_col=0)
SpotifyTracks_1957 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1957.csv', index_col=0)
SpotifyTracks_1956 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1956.csv', index_col=0)
SpotifyTracks_1955 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1955.csv', index_col=0)
SpotifyTracks_1954 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1954.csv', index_col=0)
SpotifyTracks_1953 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1953.csv', index_col=0)
SpotifyTracks_1952 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1952.csv', index_col=0)
SpotifyTracks_1951 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1951.csv', index_col=0)
SpotifyTracks_1950 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1950.csv', index_col=0)
SpotifyTracks_1949 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1949.csv', index_col=0)
SpotifyTracks_1948 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1948.csv', index_col=0)
SpotifyTracks_1947 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1947.csv', index_col=0)
SpotifyTracks_1946 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1946.csv', index_col=0)
SpotifyTracks_1945 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1945.csv', index_col=0)
SpotifyTracks_1944 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1944.csv', index_col=0)
SpotifyTracks_1943 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1943.csv', index_col=0)
SpotifyTracks_1942 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1942.csv', index_col=0)
SpotifyTracks_1941 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1941.csv', index_col=0)
SpotifyTracks_1940 = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracks_1940.csv', index_col=0)

# %%
# merge all the data sets.
SpotifyTracksData = pd.concat([SpotifyTracks_2020, SpotifyTracks_2019, SpotifyTracks_2018, SpotifyTracks_2017, SpotifyTracks_2016, 
                 SpotifyTracks_2015, SpotifyTracks_2014, SpotifyTracks_2013, SpotifyTracks_2012, SpotifyTracks_2011, 
                 SpotifyTracks_2010, SpotifyTracks_2009, SpotifyTracks_2008, SpotifyTracks_2007, SpotifyTracks_2006, 
                 SpotifyTracks_2006, SpotifyTracks_2005, SpotifyTracks_2004, SpotifyTracks_2003, SpotifyTracks_2002, 
                 SpotifyTracks_2001, SpotifyTracks_2000, SpotifyTracks_1999, SpotifyTracks_1998, SpotifyTracks_1997, 
                 SpotifyTracks_1996, SpotifyTracks_1995, SpotifyTracks_1994, SpotifyTracks_1993, SpotifyTracks_1992, 
                 SpotifyTracks_1991, SpotifyTracks_1990, SpotifyTracks_1989, SpotifyTracks_1988, SpotifyTracks_1987, 
                 SpotifyTracks_1986, SpotifyTracks_1985, SpotifyTracks_1984, SpotifyTracks_1983, SpotifyTracks_1982, 
                 SpotifyTracks_1981, SpotifyTracks_1980, SpotifyTracks_1979, SpotifyTracks_1978, SpotifyTracks_1977, 
                 SpotifyTracks_1976, SpotifyTracks_1975, SpotifyTracks_1974, SpotifyTracks_1973, SpotifyTracks_1972, 
                 SpotifyTracks_1971, SpotifyTracks_1970, SpotifyTracks_1969, SpotifyTracks_1968, SpotifyTracks_1967, 
                 SpotifyTracks_1966, SpotifyTracks_1965, SpotifyTracks_1964, SpotifyTracks_1963, SpotifyTracks_1962, 
                 SpotifyTracks_1961, SpotifyTracks_1960, SpotifyTracks_1959, SpotifyTracks_1958, SpotifyTracks_1957, 
                 SpotifyTracks_1956, SpotifyTracks_1955, SpotifyTracks_1954, SpotifyTracks_1953, SpotifyTracks_1952, 
                 SpotifyTracks_1951, SpotifyTracks_1950, SpotifyTracks_1949, SpotifyTracks_1948, SpotifyTracks_1947, 
                 SpotifyTracks_1946, SpotifyTracks_1945, SpotifyTracks_1944, SpotifyTracks_1943, SpotifyTracks_1942, 
                 SpotifyTracks_1941, SpotifyTracks_1940], sort=False, ignore_index=False)

#SpotifyData.drop('Unnamed:0', inplace=True)

# show the data frame shape.
print(SpotifyTracksData.shape)
# show the data frame with headers.
SpotifyTracksData.head()
# Out:
# (152678, 17)
#      artist_name  ... time_signature
# 0         Future  ...              4
# 1         Eminem  ...              4
# 2  Billie Eilish  ...              4
# 3     The Weeknd  ...              4
# 4  Justin Bieber  ...              4
#
# [5 rows x 17 columns]

# %%
# group entries by artist_name and track_name, check for duplicates.
grouped = SpotifyTracksData.groupby(['artist_name','track_name'], as_index=True).size()
print(grouped[grouped > 1].count())
SpotifyData.drop_duplicates(subset=['artist_name','track_name'], inplace=True)
# Out:
# 7972

# %%
# verify duplicates were dropped.
grouped = SpotifyTracksData.groupby(['artist_name','track_name'], as_index=True).size()
print(grouped[grouped > 1].count())
# Out:
# 7972

# %%
# show the data frame shape.
print(SpotifyTracksData.shape)
# show the data frame with headers.
SpotifyTracksData.head()
# Out:
# (152678, 17)
#      artist_name  ... time_signature
# 0         Future  ...              4
# 1         Eminem  ...              4
# 2  Billie Eilish  ...              4
# 3     The Weeknd  ...              4
# 4  Justin Bieber  ...              4
#
# [5 rows x 17 columns]

# %%
# check for NA values.
SpotifyTracksData.isna().sum()
# Out:
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
from google.colab import files
SpotifyTracksData.to_csv('SpotifyTracksData.csv')
files.download('SpotifyTracksData.csv')

# %% [markdown]
# ### Query for Genre.

# %%
# merge all the data sets.
SpotifyGenre_alternative = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_alternative.csv', index_col=0)
SpotifyGenre_alternativerock = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_alternativerock.csv', index_col=0)
SpotifyGenre_blues = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_blues.csv', index_col=0)
SpotifyGenre_classical = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_classical.csv', index_col=0)
SpotifyGenre_classicrock = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_classicrock.csv', index_col=0)
SpotifyGenre_country = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_country.csv', index_col=0)
SpotifyGenre_dance = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_dance.csv', index_col=0)
SpotifyGenre_dubstep = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_dubstep.csv', index_col=0)
SpotifyGenre_easylistening = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_easylistening.csv', index_col=0)
SpotifyGenre_emo = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_emo.csv', index_col=0)
SpotifyGenre_folk = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_folk.csv', index_col=0)
SpotifyGenre_funk = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_funk.csv', index_col=0)
SpotifyGenre_garage = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_garage.csv', index_col=0)
SpotifyGenre_grime = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_grime.csv', index_col=0)
SpotifyGenre_grunge = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_grunge.csv', index_col=0)
SpotifyGenre_grungerock = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_grungerock.csv', index_col=0)
SpotifyGenre_hiphop = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_hiphop.csv', index_col=0)
SpotifyGenre_indie = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_indie.csv', index_col=0)
SpotifyGenre_jazz = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_jazz.csv', index_col=0)
SpotifyGenre_jungle = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_jungle.csv', index_col=0)
SpotifyGenre_latin = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_latin.csv', index_col=0)
SpotifyGenre_metal = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_metal.csv', index_col=0)
SpotifyGenre_mod = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_mod.csv', index_col=0)
SpotifyGenre_motown = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_motown.csv', index_col=0)
SpotifyGenre_opera = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_opera.csv', index_col=0)
SpotifyGenre_pop = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_pop.csv', index_col=0)
SpotifyGenre_poprock = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_poprock.csv', index_col=0)
SpotifyGenre_punk = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_punk.csv', index_col=0)
SpotifyGenre_rap = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_rap.csv', index_col=0)
SpotifyGenre_rb = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_rb.csv', index_col=0)
SpotifyGenre_reggae = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_reggae.csv', index_col=0)
SpotifyGenre_rock = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_rock.csv', index_col=0)
SpotifyGenre_rockroll = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_rockroll.csv', index_col=0)
SpotifyGenre_soul = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_soul.csv', index_col=0)
SpotifyGenre_techno = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_techno.csv', index_col=0)
SpotifyGenre_trance = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_trance.csv', index_col=0)
SpotifyGenre_world = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenre_world.csv', index_col=0)

# %%
SpotifyGenreData = pd.concat([SpotifyGenre_alternative, SpotifyGenre_alternativerock, SpotifyGenre_blues, 
                              SpotifyGenre_classical, SpotifyGenre_classicrock, SpotifyGenre_country, 
                              SpotifyGenre_dance, SpotifyGenre_dubstep, SpotifyGenre_easylistening, 
                              SpotifyGenre_emo, SpotifyGenre_folk, SpotifyGenre_funk,
                              SpotifyGenre_garage, SpotifyGenre_grime, SpotifyGenre_grunge, 
                              SpotifyGenre_grungerock, SpotifyGenre_hiphop, SpotifyGenre_indie,
                              SpotifyGenre_jazz, SpotifyGenre_jungle, SpotifyGenre_latin, 
                              SpotifyGenre_metal, SpotifyGenre_mod, SpotifyGenre_motown,
                              SpotifyGenre_opera, SpotifyGenre_pop, SpotifyGenre_poprock, 
                              SpotifyGenre_punk, SpotifyGenre_rap, SpotifyGenre_rb,
                              SpotifyGenre_reggae, SpotifyGenre_rock, SpotifyGenre_rockroll, 
                              SpotifyGenre_soul, SpotifyGenre_techno, SpotifyGenre_trance,
                              SpotifyGenre_world], sort=False, ignore_index=False)

# show the data frame shape.
print(SpotifyGenreData.shape)
# show the data frame with headers.
SpotifyGenreData.head()
# Out:
# (68827, 17)
#      artist_name                track_name  ... duration_ms  time_signature
# 0  Trevor Daniel                   Falling  ...      159382               4
# 1           Joji  SLOW DANCING IN THE DARK  ...      209274               4
# 2         Khalid           Know Your Worth  ...      181436               4
# 3           Joji                       Run  ...      195000               3
# 4         Khalid                    Eleven  ...      206361               4
#
# [5 rows x 17 columns]

# %%
# group entries by artist_name and track_name, check for duplicates.
grouped = SpotifyGenreData.groupby(['artist_name','track_name'], as_index=True).size()
print(grouped[grouped > 1].count())
SpotifyGenreData.drop_duplicates(subset=['artist_name','track_name'], inplace=True)
# Out:
# 11479

# %%
# verify duplicates were dropped.
grouped_after_dropping = SpotifyGenreData.groupby(['artist_name','track_name'], as_index=True).size()
grouped_after_dropping[grouped_after_dropping > 1].count()
# Out:
# 0

# %%
# show the data frame shape.
print(SpotifyGenreData.shape)
# show the data frame with headers.
SpotifyGenreData.head()
# Out:
# (47668, 17)
#      artist_name                track_name  ... duration_ms  time_signature
# 0  Trevor Daniel                   Falling  ...      159382               4
# 1           Joji  SLOW DANCING IN THE DARK  ...      209274               4
# 2         Khalid           Know Your Worth  ...      181436               4
# 3           Joji                       Run  ...      195000               3
# 4         Khalid                    Eleven  ...      206361               4
#
# [5 rows x 17 columns]

# %%
# check for NA values.
SpotifyGenreData.isna().sum()
# Out:
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
from google.colab import files
SpotifyGenreData.to_csv('SpotifyGenreData.csv')
files.download('SpotifyGenreData.csv')

# %% [markdown]
# ### Final Data Set.

# %%
# read in all the spotify query data on year.
SpotifyTracksData = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyTracksData.csv', index_col=0)
SpotifyGenreData = pd.read_csv('https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyGenreData.csv', index_col=0)

# %%
SpotifyData = pd.concat([SpotifyTracksData, SpotifyGenreData], sort=False, ignore_index=False)

# show the data frame shape.
print(SpotifyData.shape)
# show the data frame with headers.
SpotifyData.head()
# Out:
# (200346, 17)
#      artist_name  ... time_signature
# 0         Future  ...              4
# 1         Eminem  ...              4
# 2  Billie Eilish  ...              4
# 3     The Weeknd  ...              4
# 4  Justin Bieber  ...              4
#
# [5 rows x 17 columns]

# %%
# group entries by artist_name and track_name, check for duplicates.
grouped = SpotifyData.groupby(['artist_name','track_name'], as_index=True).size()
print(grouped[grouped > 1].count())
SpotifyData.drop_duplicates(subset=['artist_name','track_name'], inplace=True)
# Out:
# 28745

# %%
# verify duplicates were dropped.
grouped_after_dropping = SpotifyData.groupby(['artist_name','track_name'], as_index=True).size()
grouped_after_dropping[grouped_after_dropping > 1].count()
# Out:
# 0

# %%
# show the data frame shape.
print(SpotifyData.shape)
# show the data frame with headers.
SpotifyData.head()
# Out:
# (167533, 17)
#      artist_name  ... time_signature
# 0         Future  ...              4
# 1         Eminem  ...              4
# 2  Billie Eilish  ...              4
# 3     The Weeknd  ...              4
# 4  Justin Bieber  ...              4
#
# [5 rows x 17 columns]

# %%
# check for NA values.
SpotifyData.isna().sum()
# Out:
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
from google.colab import files
SpotifyData.to_csv('SpotifyData.csv', index=False)
files.download('SpotifyData.csv')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/spotify-song-suggester-1/SpotifyData/master/SpotifyData/SpotifyData.csv")

# %%
print(df.shape)
df.head()
# Out:
# (167533, 17)
#      artist_name  ... time_signature
# 0         Future  ...              4
# 1         Eminem  ...              4
# 2  Billie Eilish  ...              4
# 3     The Weeknd  ...              4
# 4  Justin Bieber  ...              4
#
# [5 rows x 17 columns]

# %% [markdown]
# # Extra Testing.

# %%
import pandas as pd 

# read in all the spotify query data on year.
Spotify2020Dance = pd.read_csv('SpotifyGenre_2020dance.csv', index_col=0)
SpotifyDance = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/SpotifyData/SpotifyGenre_dance.csv', index_col=0)
Spotify2020 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/SpotifyData/SpotifyTracks_2020.csv', index_col=0)

# %%
print(Spotify2020Dance.shape)
print(SpotifyDance.shape)
print(Spotify2020.shape)
# Out:
# (1689, 17)
# (1866, 17)
# (1725, 17)

# %%
SpotifyData = pd.concat([Spotify2020Dance, SpotifyDance], sort=False, ignore_index=False)

# show the data frame shape.
print(SpotifyData.shape)
# show the data frame with headers.
SpotifyData.head()
# Out:
# (3555, 17)
#       artist_name           track_name  ... duration_ms  time_signature
# 0          Halsey    You should be sad  ...      205473               4
# 1    Selena Gomez  Lose You To Love Me  ...      206459               4
# 2    Selena Gomez                 Rare  ...      220590               4
# 3  Jonas Brothers  What A Man Gotta Do  ...      180645               4
# 4        Dua Lipa             Physical  ...      193829               4
#
# [5 rows x 17 columns]

# %%
# group entries by artist_name and track_name, check for duplicates.
grouped = SpotifyData.groupby(['artist_name','track_name'], as_index=True).size()
print(grouped[grouped > 1].count())
SpotifyData.drop_duplicates(subset=['artist_name','track_name'], inplace=True)
# Out:
# 294

# %%
# show the data frame shape.
print(SpotifyData.shape)
# show the data frame with headers.
SpotifyData.head()
# Out:
# (3261, 17)
#       artist_name           track_name  ... duration_ms  time_signature
# 0          Halsey    You should be sad  ...      205473               4
# 1    Selena Gomez  Lose You To Love Me  ...      206459               4
# 2    Selena Gomez                 Rare  ...      220590               4
# 3  Jonas Brothers  What A Man Gotta Do  ...      180645               4
# 4        Dua Lipa             Physical  ...      193829               4
#
# [5 rows x 17 columns]
